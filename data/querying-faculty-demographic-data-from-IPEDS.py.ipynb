# %% [markdown]
# # Querying Faculty Demographic Data from IPEDS
#
# This script queries [US IPEDS MS Access files](https://nces.ed.gov/ipeds/use-the-data/download-access-database) and generates datasets for analyzing diversity among tenured faculty.
#
# Requirements:
# * [mdb-tools](https://github.com/mdbtools/mdbtools)
#
# Tables of note:
# * `Directory Information`: contains directory information with name, address, city, state, zipcode, etc
# * `Response Status`: did the institution respond, or were the data imputed?
# * `Full-time instructional/research/public service  staff, by faculty and tenure status, academic rank, race/ethnicity, and gender (Degree-granting institutions): Fall YYYY`: Multiple records per institution.
#   * CAUTION:  Reporting Human resource data by race/ethnicity and gender is optional in even-numbered years, so many institutions will not have data.
#   * Beginning with 2016 reporting human resource data by race/ethnicity and gender is mandatory annually.
# * New hires by occupational category, race/ethnicity, and gender (Degree-granting institutions):  Fall YYYY: Multiple records per institution
#
# Other data used:
# * CCIHE2018-PublicData.xlsx: [Carnegie Classification Data](https://carnegieclassifications.iu.edu/downloads.php)
# * mrc_table10.csv: [College Level Characteristics from the Opportunity Insights College Scorecard](https://opportunityinsights.org/wp-content/uploads/2018/04/Codebook-MRC-Table-10.pdf)

# %% [markdown]
# # Configuration

# %%
## LOAD LIBRARIES
from plotnine import ggplot, aes, geom_line
import numpy as np
import pandas as pd

import statsmodels.api as sm
import statsmodels.formula.api as smf

from collections import defaultdict, Counter
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot
import glob, os, sys, subprocess # for accessing mdb-tools
import simplejson as json
import csv
import codecs
import datetime
import copy
import re #for string matching

data_path = "/IPEDS_DATA_FOLDER/"

# %%
## Define Table Names - hand checked from IPEDSYYYYYYTablesDoc.xlsx for each year
table_info = {
    "2004-05":{
        "directory":"HD2004",
        "faculty_demographics":"S2004_F",
        "rank_columns": "2004" # which rank categories 
    },
    "2005-06":{
        "directory":"HD2005",
        "faculty_demographics":"S2005_F",
        "rank_columns": "2004" # which rank categories 
    },
    "2006-07":{
        "directory":"HD2006",
        "faculty_demographics":"S2006_F",
        "rank_columns": "2004" # which rank categories 
    },
    "2007-08":{
        "directory":"HD2007",
        "faculty_demographics":"S2007_F",
        "rank_columns": "2004" # which rank categories 
    },
    "2008-09":{
        "directory":"HD2008",
        "faculty_demographics":"S2008_F",
        "rank_columns": "2004" # which rank categories 
    },
    "2009-10":{
        "directory":"HD2009",
        "faculty_demographics":"S2009_F",
        "rank_columns": "2004" # which rank categories 
    },
    "2010-11":{
        "directory":"HD2010",
        "faculty_demographics":"S2010_F",
        "rank_columns": "2004" # which rank categories 
    },
    "2011-12":{
        "directory":"HD2011",
        "faculty_demographics":"S2011_F",
        "rank_columns": "2004" # which rank categories 
    },
    "2012-13":{
        "directory":"HD2012",
        "faculty_demographics":"S2012_IS",
        "rank_columns": "2012"
    },
    "2013-14":{
        "directory":"HD2013",
        "faculty_demographics":"S2013_IS",
        "rank_columns": "2012"
    },
    "2014-15":{
        "directory":"HD2014",
        "faculty_demographics":"S2014_IS",
        "rank_columns": "2012"
    },
    "2015-16":{
        "directory":"HD2015",
        "faculty_demographics":"S2015_IS",
        "rank_columns": "2012"
    },
    "2016-17":{
        "directory":"HD2016",
        "faculty_demographics":"S2016_IS",
        "rank_columns": "2012"
    },
    "2017-18":{
        "directory":"HD2017",
        "faculty_demographics":"S2017_IS",
        "rank_columns": "2012"
    },
    "2018-19":{
        "directory":"HD2018",
        "faculty_demographics":"S2018_IS",
        "rank_columns": "2012"
    },
    "2019-20":{
        "directory":"HD2019",
        "faculty_demographics":"S2019_IS",
        "rank_columns": "2012"
    },
    "2020-21":{
        "directory":"HD2020",
        "faculty_demographics":"S2020_IS",
        "rank_columns": "2012"
    }
}

# %% [markdown]
# # Load Files

# %%
## folders that we need to store but which
## shouldn't be included in the data. List
## folders representing provisional data for which
## we now have final data

folders_to_omit = ["IPEDS_2019-20_Provisional"]

folders = [x for x in glob.glob(data_path + "*") if x.find("zip")==-1 
           and x.find("csv")==-1 and x.find("outputs")==-1 
           and x.find("xlsx")==-1 and x.find("numbers")==-1]

data_folders = []

for folder in folders:
    include = True
    for o in folders_to_omit:
        if folder.find(o)!=-1:
            include = False
    if(include):
        data_folders.append(folder)
data_folders
# Out:
# ['/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2004-05_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2005-06_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2006-07_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2007-08_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2008-09_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2009-10_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2010-11_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2011-12_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2012-13_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2013-14_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2014-15_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2015-16_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2016-17_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2017-18_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2018-19_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2019-20_Final',
#  '/Users/nathan/Box/Projects/2021-NCES-Faculty-Data/IPEDS_2020-21_Provisional']

# %% [markdown]
# ### Load the Institution Directories

# %%
## Create institution object 
def institution():
    return {
        "UNITID":None, #ID
        "INSTNM": None, #Name (some overlap),
        "STABBR": None, #State Abbreviation
        
        ## the key for these are academic year, such as "2013-14"
        "directory_year": {},
        "faculty_demographics_year": {}
    }

institutions = defaultdict(institution)

## iterate through each folder / year and fetch metadata
## on the folder names to examine, per year
for folder in data_folders:
    if folder.find("csv") >-1 or folder.find("xlsx") >-1 or folder.find("outputs")>-1:
        continue
    year = re.match(".*?IPEDS_(.*?)_",folder).groups()[0]
    table = table_info[year]
    
    ## load file
    filename = glob.glob(folder+"/*.accdb")[0]
    directory = subprocess.Popen(['mdb-export', filename, table['directory']], stdout=subprocess.PIPE).communicate()[0].decode()
    
    counter = 0
    for row in csv.DictReader(directory.split("\n")):
        institutions[row['UNITID']]['UNITID'] = row['UNITID']
        institutions[row['UNITID']]['INSTNM'] = row['INSTNM']
        institutions[row['UNITID']]['STABBR'] = row['STABBR']
        institutions[row['UNITID']]['directory_year'][year] = row
        counter += 1
    print("{0}: Loaded {1} institutions".format(year, counter))
# Out:
# 2004-05: Loaded 6916 institutions
# 2005-06: Loaded 7018 institutions
# 2006-07: Loaded 7052 institutions
# 2007-08: Loaded 7052 institutions
# 2008-09: Loaded 7126 institutions
# 2009-10: Loaded 7316 institutions
# 2010-11: Loaded 7503 institutions
# 2011-12: Loaded 7643 institutions
# 2012-13: Loaded 7735 institutions
# 2013-14: Loaded 7764 institutions
# 2014-15: Loaded 7687 institutions
# 2015-16: Loaded 7647 institutions
# 2016-17: Loaded 7521 institutions
# 2017-18: Loaded 7153 institutions
# 2018-19: Loaded 6857 institutions
# 2019-20: Loaded 6559 institutions
# 2020-21: Loaded 6440 institutions

# %% [markdown]
# ## Load Student Demographic Records (to identify primarily-white institutions)
# PWI doesn't have an agreed-on definition.  I found a graduate thesis that labeled an institution a PWI if it was not listed as an HBCU or HSI. I plan to label institutions as a PWI based on the percentage of white students reported in the most recent datafile. Institutions with more than 50% white students will be labeled PWIs.

# %%
pct_white_column = "PCTENRWH"

## set up variables for loading the most recent table
folder = [folder for folder in data_folders if folder.find("csv") ==-1 and folder.find("xlsx") ==-1 and folder.find("outputs") == -1][-1]
year = re.match(".*?IPEDS_(.*?)_",folder).groups()[0]
filename = glob.glob(folder+"/*.accdb")[0]
deriv_variable_tablename = "DRVEF" + year[0:4]

## load raw table text into table_data
table_data = subprocess.Popen(['mdb-export', filename, deriv_variable_tablename], stdout=subprocess.PIPE).communicate()[0].decode()

## load table_data into a dict for determining primarily-white-institutions
institution_pwi = {}
for row in csv.DictReader(table_data.split("\n")):
    # set UNITID key, since capitalization is inconsistent between years
    unitid_key = "UNITID"
    if(unitid_key not in row.keys()):
        unitid_key = "UnitID"
    unitid = row[unitid_key]
    
    if(pct_white_column in row.keys()):
        pct_white = int(row[pct_white_column])
    else:
        pct_white = None
    institution_pwi[unitid] = pct_white

# %% [markdown]
# ## Load the Faculty Demographics Records

# %%
for folder in data_folders:
    if folder.find("csv") >-1 or folder.find("xlsx") >-1 or folder.find("outputs")>-1:
        continue
    year = re.match(".*?IPEDS_(.*?)_",folder).groups()[0]
    table = table_info[year]
    
    ## load file
    filename = glob.glob(folder+"/*.accdb")[0]
    table_data = subprocess.Popen(['mdb-export', filename, table['faculty_demographics']], stdout=subprocess.PIPE).communicate()[0].decode()
    
    
    counter = 0
    for row in csv.DictReader(table_data.split("\n")):
        
        # set UNITID key, since capitalization is inconsistent between years
        unitid_key = "UNITID"
        if(unitid_key not in row.keys()):
            unitid_key = "UnitID"
        unitid = row[unitid_key]
        
        if year not in institutions[unitid]['faculty_demographics_year'].keys():
            institutions[unitid]['faculty_demographics_year'][year] = []
        institutions[unitid]['faculty_demographics_year'][year].append(row)
        counter += 1
        
    print("{0}: Loaded {1} faculty demographics records".format(year, counter))
# Out:
# 2004-05: Loaded 15472 faculty demographics records
# 2005-06: Loaded 31657 faculty demographics records
# 2006-07: Loaded 20591 faculty demographics records
# 2007-08: Loaded 32226 faculty demographics records
# 2008-09: Loaded 19922 faculty demographics records
# 2009-10: Loaded 32752 faculty demographics records
# 2010-11: Loaded 19502 faculty demographics records
# 2011-12: Loaded 33065 faculty demographics records
# 2012-13: Loaded 39998 faculty demographics records
# 2013-14: Loaded 65237 faculty demographics records
# 2014-15: Loaded 40448 faculty demographics records
# 2015-16: Loaded 63410 faculty demographics records
# 2016-17: Loaded 67870 faculty demographics records
# 2017-18: Loaded 67534 faculty demographics records
# 2018-19: Loaded 66184 faculty demographics records
# 2019-20: Loaded 65135 faculty demographics records
# 2020-21: Loaded 63843 faculty demographics records

# %% [markdown]
# ### Convert IPEDS columns to human-readable columns
#
# 2004-2005 codes:
# * **ARANK:**
#   * 22: *Total full-time faculty*
#   * 1: Total full-time faculty, Tenured, Professors
#   * 2: Total full-time faculty, Tenured, Associate professors
#   * 3: Total full-time faculty, Tenured, Assistant professors
#   * <del> 4: Total full-time faculty, Tenured, Instructors</del>
#   * <del> 5: Total full-time faculty, Tenured, Lecturers</del>
#   * 6: <del> Total full-time faculty, Tenured, No academic rank</del>
#   * 7: *Total full-time faculty, Tenured total*
#   * 8: Total full-time faculty, Non-tenured on tenure track, Professors
#   * 9: Total full-time faculty, Non-tenured on tenure track, Associate professors
#   * 10: Total full-time faculty, Non-tenured on tenure track, Assistant professors
#   * <del> 11: Total full-time faculty, Non-tenured on tenure track, Instructors</del>
#   * <del> 12: Total full-time faculty, Non-tenured on tenure track, Lecturers</del>
#   * 13: <del> Total full-time faculty, Non-tenured on tenure track, No academic rank</del>
#   * 14: *Total full-time faculty, Non-tenured on tenure track total*
#
# * **Staff Columns:**
#     * STAFF19	American Indian or Alaska Native total
#     * STAFF20	Asian or Pacific Islander total
#     * STAFF21	Hispanic total
#     * STAFF22	White non-Hispanic total
#     * STAFF01	Nonresident alien men
#     * STAFF02	Nonresident alien women
#     * STAFF03	Black non-Hispanic men
#     * STAFF04	Black non-Hispanic women
#     * STAFF05	American Indian or Alaska Native men
#     * STAFF06	American Indian or Alaska Native women
#     * STAFF07	Asian or Pacific Islander men
#     * STAFF08	Asian or Pacific Islander women
#     * STAFF09	Hispanic men
#     * STAFF10	Hispanic women
#     * STAFF11	White non-Hispanic men
#     * STAFF12	White non-Hispanic women
#     * STAFF13	Race/ethnicity unknown men
#     * STAFF14	Race/ethnicity unknown women
#     * STAFF15	Grand total men
#     * STAFF16	Grand total women
#     * STAFF17	Nonresident alien total
#     * STAFF18	Black non-Hispanic  total
#     * STAFF23	Race/ethnicity unknown total
#     * STAFF24	Grand total

# %% [markdown]
# ### Metadata for Querying Records and Merging Columns

# %%
## since the rows change and the meaning of the integers change
## at certain points, I have created these methods and placed
## them into a dict so the right method can be called for the
## right piece of information, depending on what year the record is from

def rank_2004_total_tenured(row):
    return row['ARANK']=='7'

## non_tenured is different from untenured tenure-track
def rank_2004_total_non_tenured(row):
    return row['ARANK']=='14'

def rank_2004_tenured_full(row):
    return row['ARANK']=='1'
def rank_2004_tenured_associate(row):
    return row['ARANK']=='2'
def rank_2004_tenured_assistant(row):
    return row['ARANK']=='3'

## non_tenured is different from untenured tenure-track
def rank_2004_non_tenured_full(row):
    return row['ARANK']=='8'
## non_tenured is different from untenured tenure-track
def rank_2004_non_tenured_associate(row):
    return row['ARANK']=='9'
## non_tenured is different from untenured tenure-track
def rank_2004_non_tenured_assistant(row):
    return row['ARANK']=='10'

## return empty list for categories that 
## don't exist in the 2004 data
def rank_2004_no_values(row):
    return []

rank_2004 = {
    "rank_object":           "2004",
    "tenured":         rank_2004_total_tenured,
    "non_tenured":     rank_2004_total_non_tenured,
    "un_tenured":      rank_2004_no_values,

    "tenured_full":          rank_2004_tenured_full,
    "tenured_associate":     rank_2004_tenured_associate,
    "tenured_assistant":     rank_2004_tenured_assistant,
    
    "non_tenured_full":      rank_2004_non_tenured_full,
    "non_tenured_associate": rank_2004_non_tenured_associate,
    "non_tenured_assistant": rank_2004_non_tenured_assistant,
    
    "un_tenured_full":       rank_2004_no_values,
    "un_tenured_associate":  rank_2004_no_values,
    "un_tenured_assistant":  rank_2004_no_values
}

## CREATE A DICT FOR HUMAN READABLE COLUMNS

# different keys different years for nonresidents
# STAFF prefixes are before 2010-11
# HR prefixes are from 2010-11 to 2011-12 
col_keys = {"STAFF19":"American Indian or Alaska Native total",
             "HRAIANT":"American Indian or Alaska Native total",

             "STAFF05":"American Indian or Alaska Native men",
             "HRAIANM":"American Indian or Alaska Native men",

             "STAFF06":"American Indian or Alaska Native women",
             "HRAIANW":"American Indian or Alaska Native women",

            ## Changes to Black or African American in 2010-11
             "STAFF18":"Black non-Hispanic total",             
             "STAFF03":"Black non-Hispanic men",             
             "STAFF04":"Black non-Hispanic women",

             ## Changes to Asian | Native Hawaiian or Other Pacific Islander in 2010-11            
             "STAFF20":"Asian or Pacific Islander total",
             "STAFF07":"Asian or Pacific Islander men",
             "STAFF08":"Asian or Pacific Islander women",

             ## Changes to Hispanic or Latino Men in 2010-11
             "STAFF21":"Hispanic total",
             "STAFF09":"Hispanic men",
             "STAFF10":"Hispanic women",

             ## Changes to White in 2010-11
             "STAFF22":"White non-Hispanic total",
             "STAFF11":"White non-Hispanic men",             
             "STAFF12":"White non-Hispanic women",

             # Race/ethnicity unknown
             "STAFF23":"Race/ethnicity unknown total",
             "HRUNKNT":"Race/ethnicity unknown total",
             
             "STAFF13":"Race/ethnicity unknown men",
             "HRUNKNM":"Race/ethnicity unknown men",
             
             "STAFF14":"Race/ethnicity unknown women",
             "HRUNKNW":"Race/ethnicity unknown women",
             
             # Grand Totals
             "STAFF24":"Grand total",
             "HRTOTLT":"Grand total",

             "STAFF15":"Grand total men",
             "HRTOTLM":"Grand total men",
             
             "STAFF16":"Grand total women",
             "HRTOTLW":"Grand total women",

             # Nonresident alien
             "STAFF17":"Nonresident alien total",
             "HRNRALT":"Nonresident alien total",
             
             "STAFF01":"Nonresident alien men", 
             "HRNRALM":"Nonresident alien men",
             
             "STAFF02":"Nonresident alien women",
             "HRNRALW":"Nonresident alien women",
             
             
             ## Not included datasets before 2010-11
             "HRASIAT":"Asian total",
             "HRASIAM":"Asian men",
             "HRASIAW":"Asian women",
             "HRBKAAT":"Black or African American total",
             "HRBKAAM":"Black or African American men",
             "HRBKAAW":"Black or African American women", 
             "HRHISPT":"Hispanic or Latino total",
             "HRHISPM":"Hispanic or Latino men",
             "HRHISPW":"Hispanic or Latino women",
             "HRNHPIT":"Native Hawaiian or Other Pacific Islander total", 
             "HRNHPIM":"Native Hawaiian or Other Pacific Islander men", 
             "HRNHPIW":"Native Hawaiian or Other Pacific Islander women",
             "HRWHITT":"White total",
             "HRWHITM":"White men",
             "HRWHITW":"White women", 
             "HR2MORT":"Two or more races total",
             "HR2MORM":"Two or more races men",
             "HR2MORW":"Two or more races women"  
            }

# %% [markdown]
# ### Metadata for Querying Records from 2012-13 through 2018-19¶

# %%
def rank_2012_total_tenured(row):
    return row['ARANK']=='0' and row['SISCAT'] == '200'

# un-tenured and on tenure track
def rank_2012_total_un_tenured(row):
    return row['ARANK']=='0' and row['SISCAT'] == '300'

def rank_2012_tenured_full(row):
    return row['ARANK']=='1' and row['SISCAT'] == '201'
def rank_2012_tenured_associate(row):
    return row['ARANK']=='2' and row['SISCAT'] == '202'
def rank_2012_tenured_assistant(row):
    return row['ARANK']=='3' and row['SISCAT'] == '203'
def rank_2012_un_tenured_full(row):
    return row['ARANK']=='1' and row['SISCAT'] == '301'
def rank_2012_un_tenured_associate(row):
    return row['ARANK']=='2' and row['SISCAT'] == '302'
def rank_2012_un_tenured_assistant(row):
    return row['ARANK']=='3' and row['SISCAT'] == '303'

## return empty list for categories that 
## don't exist in the 2012 data and onward
def rank_2012_no_values(row):
    return []


rank_2012 = {
    "rank_object":           "2012",
    "tenured":         rank_2012_total_tenured,
    "non_tenured":     rank_2012_no_values,
    "un_tenured":      rank_2012_total_un_tenured,

    "tenured_full":          rank_2012_tenured_full,
    "tenured_associate":     rank_2012_tenured_associate,
    "tenured_assistant":     rank_2012_tenured_assistant,
        
    "un_tenured_full":       rank_2012_un_tenured_full,
    "un_tenured_associate":  rank_2012_un_tenured_associate,
    "un_tenured_assistant":  rank_2012_un_tenured_assistant,
    
    ## NOTE: these are actually available
    ## but I don't know how well they correspond
    ## to how things were collected in the 2004+ period
    ## so I'm omitting them to avoid confusion
    "non_tenured_full":      rank_2012_no_values,
    "non_tenured_associate": rank_2012_no_values,
    "non_tenured_assistant": rank_2012_no_values

}

# %% [markdown]
# ### Process Data for a Single Institution

# %%
## pull out Cornell for initial prototyping and data validation
# institution_match_string = "Michigan"

# [(x['UNITID'], x['INSTNM']) for x in institutions.values() if x['INSTNM'].find(institution_match_string)!=-1]

#institution = institutions['190415']
#institution_name = "Cornell University"

#institution = institutions['186131']
#institution_name = 'Princeton University'

# institution = institutions['166683']
# institution_name = 'Massachusetts Institute of Technology'

# institution = institutions['170976']
# institution_name = 'University of Michigan-Ann Arbor'

# %%
# fetch all rows for an institution. Note: this makes heavy
# use of globals
def rows_for_institution(institution):
    
    ## for a given university, iterate through the rank rows 
    ## and collapse them into a single row with many columns
    all_rows = []
    institution_name = institution['INSTNM']

    for year in institution['faculty_demographics_year'].keys():
        new_row = {}
        new_row['year'] = year
        new_row['UNITID'] = institution['UNITID']
        new_row['INSTNM'] = institution['INSTNM']
        new_row['STABBR'] = institution['STABBR']
        if table_info[year]['rank_columns'] =='2004':
            rank_object = rank_2004
            new_row['schema'] = "2004"
        else:
            rank_object = rank_2012
            new_row['schema'] = "2012"
        
#         ## set the grand totals by looking for totals
#         rows = [x for x in institution['faculty_demographics_year'][year] if x['ARANK'] =='0' and x['SISCAT'] in ['200', '300']]
#         try:
#             tenured_un_tenured_total = np.sum([int(x['STAFF24']) for x in rows])
#         except:
#             tenured_un_tenured_total = np.sum([int(x['HRTOTLT']) for x in rows])
            
#         new_row["tenured_un_tenured_Grand_total"] = tenured_un_tenured_total
        
        for rank in rank_object.keys():
            if(rank =="rank_object"):
                continue
            rows = [x for x in institution['faculty_demographics_year'][year] if rank_object[rank](x)]
            for key, new_key in col_keys.items():
                full_key = rank + "_" + new_key.replace(" ","_").replace("/","_")
                if(len(rows)>0):
                    if(key in rows[0].keys()):
                        try:
                            new_row[full_key] = int(rows[0][key])
                        except:
                            new_row[full_key] = None # empty column
                    elif(full_key not in new_row.keys()):
                        new_row[full_key] = None
                else:
                    new_row[full_key] = None
        
        tenured_un_tenured_grand_total = 0
        if(new_row['non_tenured_Grand_total'] is not None):
            tenured_un_tenured_grand_total += int(new_row['non_tenured_Grand_total'])
        if(new_row['un_tenured_Grand_total'] is not None): 
            tenured_un_tenured_grand_total += int(new_row['un_tenured_Grand_total'])
        if(new_row['tenured_Grand_total'] is not None): 
            tenured_un_tenured_grand_total += int(new_row['tenured_Grand_total'])
            
        new_row['tenured_un_tenured_Grand_total'] = tenured_un_tenured_grand_total
        
        all_rows.append(new_row)

    print("Created {0} rows (years) for {1}".format(len(all_rows), institution_name))
    return all_rows

# %%
#institutions['100654']['faculty_demographics_year']['2004-05']

# %% [markdown]
# # Fetch longitudinal data for all institutions

# %%
all_institution_records = []
included_institutions   = []

for key, institution in institutions.items():
    all_records = rows_for_institution(institution)
    
    if(len(all_records)>0):
        all_institution_records += all_records
        included_institutions.append({"UNITID":all_records[0]['UNITID'],
                                      "INSTNM":all_records[0]['INSTNM'], 
                                      "YEARS": len(all_records)})
# Out:
# Created 0 rows (years) for Community College of the Air Force
# Created 14 rows (years) for Alabama A & M University
# Created 15 rows (years) for University of Alabama at Birmingham
# Created 12 rows (years) for Amridge University
# Created 17 rows (years) for University of Alabama in Huntsville
# Created 17 rows (years) for Alabama State University
# Created 1 rows (years) for University of Alabama System Office
# Created 17 rows (years) for The University of Alabama
# Created 17 rows (years) for Central Alabama Community College
# Created 17 rows (years) for Athens State University
# Created 12 rows (years) for Auburn University at Montgomery
# Created 17 rows (years) for Auburn University
# Created 1 rows (years) for Lawson State Community College-Bessemer Campus
# Created 12 rows (years) for Birmingham-Southern College
# Created 1 rows (years) for Shelton State Community College-C A Fredd Campus
# Created 17 rows (years) for Chattahoochee Valley Community College
# Created 8 rows (years) for Concordia College Alabama
# Created 0 rows (years) for LURLEEN B WALLACE COMMUNITY COLLEGE-MACARTHUR CAMPUS
# Created 12 rows (years) for South University-Montgomery
# Created 17 rows (years) for Enterprise State Community College
# Created 17 rows (years) for Coastal Alabama Community College
# Created 13 rows (years) for Faulkner University
# Created 0 rows (years) for Gadsden Business College
# Created 17 rows (years) for Gadsden State Community College
# Created 17 rows (years) for George C Wallace Community College-Dothan
# Created 17 rows (years) for George C Wallace State Community College-Hanceville
# Created 17 rows (years) for George C Wallace State Community College-Selma
# Created 0 rows (years) for GADSDEN STATE COMMUNITY COLLEGE-AYERS CAMPUS
# Created 11 rows (years) for Herzing University-Birmingham
# Created 17 rows (years) for Huntingdon College
# Created 17 rows (years) for Heritage Christian University
# Created 17 rows (years) for J. F. Drake State Community and Technical College
# Created 17 rows (years) for J F Ingram State Technical College
# Created 17 rows (years) for Jacksonville State University
# Created 14 rows (years) for Jefferson Davis Community College
# Created 17 rows (years) for Jefferson State Community College
# Created 17 rows (years) for John C Calhoun State Community College
# Created 0 rows (years) for H COUNCILL TRENHOLM STATE TECHNICAL COLLEGE-PATTERSON CAMPUS
# Created 16 rows (years) for Judson College
# Created 17 rows (years) for Lawson State Community College
# Created 12 rows (years) for University of West Alabama
# Created 17 rows (years) for Lurleen B Wallace Community College
# Created 17 rows (years) for Marion Military Institute
# Created 13 rows (years) for Miles College
# Created 11 rows (years) for University of Mobile
# Created 17 rows (years) for University of Montevallo
# Created 17 rows (years) for Northwest-Shoals Community College
# Created 15 rows (years) for University of North Alabama
# Created 17 rows (years) for Northeast Alabama Community College
# Created 16 rows (years) for Oakwood University
# Created 14 rows (years) for Alabama Southern Community College
# Created 0 rows (years) for Prince Institute-Southeast
# Created 17 rows (years) for Reid State Technical College
# Created 17 rows (years) for Bishop State Community College
# Created 13 rows (years) for Samford University
# Created 17 rows (years) for Shelton State Community College
# Created 17 rows (years) for Snead State Community College
# Created 15 rows (years) for University of South Alabama
# Created 0 rows (years) for Southern Community College
# Created 17 rows (years) for Spring Hill College
# Created 11 rows (years) for Southeastern Bible College
# Created 15 rows (years) for Stillman College
# Created 12 rows (years) for Talladega College
# Created 17 rows (years) for H Councill Trenholm State Community College
# Created 1 rows (years) for Troy State University-Dothan Campus
# Created 1 rows (years) for Troy State University-Montgomery
# Created 17 rows (years) for Troy University
# Created 11 rows (years) for Tuskegee University
# Created 13 rows (years) for United States Sports Academy
# Created 17 rows (years) for Bevill State Community College
# Created 17 rows (years) for University of Alaska Anchorage
# Created 17 rows (years) for University of Alaska Fairbanks
# Created 17 rows (years) for University of Alaska Southeast
# Created 13 rows (years) for Alaska Pacific University
# Created 2 rows (years) for Alaska Vocational Technical Center
# Created 13 rows (years) for Charter College
# Created 10 rows (years) for Prince William Sound Community College
# Created 1 rows (years) for Sheldon Jackson College
# Created 8 rows (years) for Alaska Career College
# Created 4 rows (years) for University of Alaska System of Higher Education
# Created 5 rows (years) for Everest College-Phoenix
# Created 9 rows (years) for Collins College
# Created 0 rows (years) for Empire Beauty School-Paradise Valley
# Created 0 rows (years) for Empire Beauty School-Tucson
# Created 9 rows (years) for Thunderbird School of Global Management
# Created 7 rows (years) for American Indian College Inc
# Created 0 rows (years) for American Institute of Trucking
# Created 15 rows (years) for Carrington College-Phoenix North
# Created 10 rows (years) for Carrington College-Mesa
# Created 8 rows (years) for Carrington College-Tucson
# Created 7 rows (years) for CollegeAmerica-Flagstaff
# Created 0 rows (years) for Arizona Academy of Beauty-East
# Created 3 rows (years) for Platt College-Arizona Automotive Institute Arizona
# Created 11 rows (years) for Brookline College-Phoenix
# Created 17 rows (years) for Arizona State University Campus Immersion
# Created 11 rows (years) for Arizona Western College
# Created 16 rows (years) for University of Arizona
# Created 9 rows (years) for Southwest University of Visual Arts-Tucson
# Created 0 rows (years) for Brillare Hairdressing Academy
# Created 13 rows (years) for Central Arizona College
# Created 9 rows (years) for Brown Mackie College-Tucson
# Created 0 rows (years) for Charles of Italy Beauty College
# Created 17 rows (years) for Cochise County Community College District
# Created 0 rows (years) for Empire Beauty School-Flagstaff
# Created 0 rows (years) for Empire Beauty School-Chandler
# Created 0 rows (years) for Cortiva Institute-Tucson
# Created 0 rows (years) for DeVoe College of Beauty
# Created 8 rows (years) for DeVry University-Arizona
# Created 0 rows (years) for Avalon School of Cosmetology-Mesa
# Created 17 rows (years) for Eastern Arizona College
# Created 14 rows (years) for Embry-Riddle Aeronautical University-Prescott
# Created 14 rows (years) for Glendale Community College
# Created 11 rows (years) for Grand Canyon University
# Created 5 rows (years) for Anthem College-Phoenix
# Created 0 rows (years) for Olympian Academy of Cosmetology
# Created 7 rows (years) for Lamson College
# Created 8 rows (years) for Kaplan College-Phoenix
# Created 0 rows (years) for Maricopa Beauty College LLC
# Created 1 rows (years) for Maricopa Community College System Office
# Created 14 rows (years) for GateWay Community College
# Created 14 rows (years) for Mesa Community College
# Created 11 rows (years) for ITT Technical Institute-Tucson
# Created 11 rows (years) for ITT Technical Institute-Tempe
# Created 13 rows (years) for Mohave Community College
# Created 0 rows (years) for Universal Technical Institute of Arizona Inc-Motorcycle Mechanics Institute Division
# Created 0 rows (years) for Mundus Institute
# Created 17 rows (years) for Dine College
# Created 17 rows (years) for Northern Arizona University
# Created 14 rows (years) for Northland Pioneer College
# Created 13 rows (years) for Ottawa University-Phoenix
# Created 0 rows (years) for Empire Beauty School-Glendale
# Created 14 rows (years) for Phoenix College
# Created 0 rows (years) for Cortiva Institute-Scottsdale
# Created 9 rows (years) for University of Phoenix-Phoenix Campus
# Created 12 rows (years) for Pima Community College
# Created 11 rows (years) for Pima Medical Institute-Tucson
# Created 11 rows (years) for Pima Medical Institute-Albuquerque
# Created 15 rows (years) for Prescott College
# Created 14 rows (years) for Refrigeration School Inc
# Created 14 rows (years) for Rio Salado College
# Created 0 rows (years) for Roberto-Venn School of Luthiery
# Created 0 rows (years) for Hair Academy of Safford
# Created 14 rows (years) for Scottsdale Community College
# Created 14 rows (years) for South Mountain Community College
# Created 1 rows (years) for Long Technical College-East Valley
# Created 10 rows (years) for Arizona Christian University
# Created 0 rows (years) for Tucson College
# Created 14 rows (years) for Universal Technical Institute of Arizona Inc
# Created 1 rows (years) for Metropolitan College
# Created 8 rows (years) for Western International University
# Created 0 rows (years) for Empire Beauty School-NW Phoenix
# Created 13 rows (years) for Yavapai College
# Created 16 rows (years) for University of Arkansas at Little Rock
# Created 11 rows (years) for University of Arkansas for Medical Sciences
# Created 0 rows (years) for ABC Beauty College Inc
# Created 11 rows (years) for Arkansas Baptist College
# Created 0 rows (years) for Arkansas Beauty School-Little Rock
# Created 12 rows (years) for Lyon College
# Created 0 rows (years) for Arkansas College of Barbering and Hair Design
# Created 0 rows (years) for Arthur's Beauty College
# Created 17 rows (years) for University of Arkansas
# Created 16 rows (years) for University of Arkansas at Pine Bluff
# Created 11 rows (years) for Arkansas State University-Beebe
# Created 16 rows (years) for Arkansas State University
# Created 17 rows (years) for Arkansas Tech University
# Created 17 rows (years) for University of Arkansas at Monticello
# Created 0 rows (years) for Arthur's Beauty College
# Created 6 rows (years) for Baptist Health College Little Rock
# Created 0 rows (years) for Bee Jays Academy
# Created 17 rows (years) for Black River Technical College
# Created 13 rows (years) for University of Central Arkansas
# Created 15 rows (years) for Central Baptist College
# Created 0 rows (years) for Blytheville Academy of Cosmetology
# Created 15 rows (years) for Cossatot Community College of the University of Arkansas
# Created 12 rows (years) for Crowley's Ridge College
# Created 0 rows (years) for Crowley's Ridge Technical Institute
# Created 0 rows (years) for De Luxe Beauty School
# Created 13 rows (years) for East Arkansas Community College
# Created 0 rows (years) for Eastern College of Health Vocations-Little Rock
# Created 0 rows (years) for Paul Mitchell the School-Little Rock
# Created 11 rows (years) for National Park College
# Created 12 rows (years) for University of Arkansas Community College-Batesville
# Created 0 rows (years) for Harding University Graduate School of Religion
# Created 12 rows (years) for Harding University
# Created 15 rows (years) for Henderson State University
# Created 12 rows (years) for Hendrix College
# Created 0 rows (years) for Hot Springs Beauty College
# Created 0 rows (years) for Jefferson Regional Medical Center School of Nursing
# Created 11 rows (years) for John Brown University
# Created 0 rows (years) for Lees School of Cosmetology
# Created 0 rows (years) for Career Academy of Hair Design
# Created 0 rows (years) for Marsha Kay Beauty College
# Created 0 rows (years) for Academy of Salon and Spa
# Created 0 rows (years) for Mellies School of Modeling
# Created 16 rows (years) for Arkansas State University Mid-South
# Created 16 rows (years) for Arkansas Northeastern College
# Created 0 rows (years) for Margaret's Hair Academy Inc
# Created 0 rows (years) for New Tyler Barber College Inc
# Created 12 rows (years) for North Arkansas College
# Created 0 rows (years) for Northwest Technical Institute
# Created 14 rows (years) for Ouachita Baptist University
# Created 17 rows (years) for Arkansas State University Three Rivers
# Created 16 rows (years) for Ozarka College
# Created 12 rows (years) for University of the Ozarks
# Created 16 rows (years) for University of Arkansas Community College-Morrilton
# Created 14 rows (years) for Philander Smith College
# Created 11 rows (years) for Phillips Community College of the University of Arkansas
# Created 15 rows (years) for Southeast Arkansas College
# Created 0 rows (years) for Professional Cosmetology Education Center
# Created 12 rows (years) for University of Arkansas-Pulaski Technical College
# Created 15 rows (years) for University of Arkansas Hope-Texarkana
# Created 11 rows (years) for University of Arkansas Community College Rich Mountain
# Created 0 rows (years) for Paul Mitchell the School-Arkansas
# Created 0 rows (years) for Searcy Beauty College
# Created 12 rows (years) for Williams Baptist University
# Created 0 rows (years) for SOUTHERN INSTITUTE OF COSMETOLOGY
# Created 14 rows (years) for South Arkansas Community College
# Created 11 rows (years) for Southern Arkansas University Main Campus
# Created 17 rows (years) for Southern Arkansas University Tech
# Created 0 rows (years) for University of Arkansas System Office
# Created 0 rows (years) for Velvatex College of Beauty Culture
# Created 15 rows (years) for University of Arkansas-Fort Smith
# Created 13 rows (years) for Academy of Art University
# Created 11 rows (years) for ITT Technical Institute-Rancho Cordova
# Created 2 rows (years) for Academy of Chinese Culture and Health Sciences
# Created 0 rows (years) for Academy of Professional Careers
# Created 0 rows (years) for The Academy of Radio and TV Broadcasting
# Created 0 rows (years) for Academy Pacific Travel College
# Created 0 rows (years) for Avalon School of Cosmetology-Alameda
# Created 15 rows (years) for College of Alameda
# Created 17 rows (years) for Allan Hancock College
# Created 13 rows (years) for American Academy of Dramatic Arts-Los Angeles
# Created 4 rows (years) for Berkeley School of Theology
# Created 11 rows (years) for American Film Institute Conservatory
# Created 0 rows (years) for American Beauty College
# Created 4 rows (years) for American InterContinental University
# Created 9 rows (years) for American Career College-Los Angeles
# Created 12 rows (years) for American Conservatory Theater
# Created 17 rows (years) for American River College
# Created 0 rows (years) for Everest College-Hayward
# Created 14 rows (years) for Antelope Valley College
# Created 11 rows (years) for Art Center College of Design
# Created 0 rows (years) for Associated Technical College-Los Angeles
# Created 0 rows (years) for Associated Technical College-San Diego
# Created 0 rows (years) for Associated Technical College
# Created 17 rows (years) for Azusa Pacific University
# Created 17 rows (years) for Bakersfield College
# Created 16 rows (years) for Barstow Community College
# Created 0 rows (years) for Bellus Academy-Chula Vista
# Created 4 rows (years) for Bethany University
# Created 9 rows (years) for Bethesda University
# Created 14 rows (years) for Biola University
# Created 3 rows (years) for Brooks College
# Created 11 rows (years) for Brooks Institute
# Created 0 rows (years) for Brownson Technical School
# Created 11 rows (years) for Bryan University
# Created 17 rows (years) for Butte College
# Created 12 rows (years) for Phillips Graduate University
# Created 12 rows (years) for California Institute of Integral Studies
# Created 0 rows (years) for CALIFORNIA PARAMEDICAL AND TECHNICAL COLLEGE
# Created 17 rows (years) for Cabrillo College
# Created 11 rows (years) for California Baptist University
# Created 11 rows (years) for California College of the Arts
# Created 12 rows (years) for University of California-Hastings College of Law
# Created 13 rows (years) for California Institute of Technology
# Created 16 rows (years) for California Lutheran University
# Created 15 rows (years) for California Polytechnic State University-San Luis Obispo
# Created 0 rows (years) for Alliant International University-System Office
# Created 3 rows (years) for Alliant International University
# Created 3 rows (years) for Alliant International University
# Created 16 rows (years) for Alliant International University-San Diego
# Created 3 rows (years) for Alliant International University
# Created 15 rows (years) for California State University-Bakersfield
# Created 15 rows (years) for California State University-Stanislaus
# Created 0 rows (years) for California State University-Chancellors Office
# Created 15 rows (years) for California State University-San Bernardino
# Created 15 rows (years) for California State Polytechnic University-Pomona
# Created 15 rows (years) for California State University-Chico
# Created 15 rows (years) for California State University-Dominguez Hills
# Created 15 rows (years) for California State University-Fresno
# Created 15 rows (years) for California State University-Fullerton
# Created 15 rows (years) for California State University-East Bay
# Created 15 rows (years) for California State University-Long Beach
# Created 15 rows (years) for California State University-Los Angeles
# Created 15 rows (years) for California State University-Northridge
# Created 15 rows (years) for California State University-Sacramento
# Created 16 rows (years) for University of California-Berkeley
# Created 15 rows (years) for University of California-Davis
# Created 15 rows (years) for University of California-Irvine
# Created 15 rows (years) for University of California-Los Angeles
# Created 16 rows (years) for University of California-Riverside
# Created 15 rows (years) for University of California-San Diego
# Created 15 rows (years) for University of California-San Francisco
# Created 16 rows (years) for University of California-Santa Barbara
# Created 16 rows (years) for University of California-Santa Cruz
# Created 12 rows (years) for Sofia University
# Created 0 rows (years) for California Beauty School
# Created 0 rows (years) for California Christian College
# Created 9 rows (years) for California College San Diego
# Created 10 rows (years) for Le Cordon Bleu College of Culinary Arts-San Francisco
# Created 0 rows (years) for California Hair Design Academy
# Created 15 rows (years) for California Institute of the Arts
# Created 15 rows (years) for California State University Maritime Academy
# Created 17 rows (years) for California Western School of Law
# Created 14 rows (years) for Canada College
# Created 11 rows (years) for College of the Canyons
# Created 0 rows (years) for Career Academy of Beauty
# Created 10 rows (years) for Casa Loma College-Van Nuys
# Created 0 rows (years) for CET-San Diego
# Created 0 rows (years) for CET-San Jose
# Created 0 rows (years) for CET-El Centro
# Created 0 rows (years) for CET-Colton
# Created 0 rows (years) for CET-Watsonville
# Created 0 rows (years) for CET-Gilroy
# Created 0 rows (years) for CET-Salinas
# Created 0 rows (years) for Computer Technologies Program
# Created 16 rows (years) for Cerritos College
# Created 17 rows (years) for Cerro Coso Community College
# Created 17 rows (years) for Chabot College
# Created 17 rows (years) for Chaffey College
# Created 17 rows (years) for Chapman University
# Created 14 rows (years) for Charles R Drew University of Medicine and Science
# Created 16 rows (years) for Concordia University-Irvine
# Created 14 rows (years) for San Diego Christian College
# Created 13 rows (years) for Church Divinity School of the Pacific
# Created 17 rows (years) for Citrus College
# Created 16 rows (years) for City College of San Francisco
# Created 0 rows (years) for CITY UNIVERSITY-LOS ANGELES
# Created 17 rows (years) for Claremont Graduate University
# Created 17 rows (years) for Claremont McKenna College
# Created 0 rows (years) for Milan Institute-Visalia
# Created 4 rows (years) for Cleveland Chiropractic College of Los Angeles
# Created 0 rows (years) for Clovis Adult Education
# Created 2 rows (years) for Coast Community College District Office
# Created 16 rows (years) for Coastline Community College
# Created 12 rows (years) for Cogswell University of Silicon Valley
# Created 13 rows (years) for Coleman University
# Created 0 rows (years) for Coba Academy
# Created 4 rows (years) for National Polytechnic College of Science
# Created 13 rows (years) for Western University of Health Sciences
# Created 17 rows (years) for Columbia College
# Created 9 rows (years) for Columbia College Hollywood
# Created 15 rows (years) for Compton College
# Created 0 rows (years) for Western Beauty Institute
# Created 0 rows (years) for Contra Costa Community College District Office
# Created 17 rows (years) for Contra Costa College
# Created 17 rows (years) for Cosumnes River College
# Created 13 rows (years) for Crafton Hills College
# Created 15 rows (years) for Cuesta College
# Created 14 rows (years) for Cuyamaca College
# Created 0 rows (years) for Marinello Schools of Beauty-Bell
# Created 17 rows (years) for Cypress College
# Created 0 rows (years) for D-Q UNIVERSITY
# Created 17 rows (years) for De Anza College
# Created 0 rows (years) for Marinello Schools of Beauty-Hemet
# Created 1 rows (years) for Dell'Arte International School of Physical Theatre
# Created 16 rows (years) for College of the Desert
# Created 3 rows (years) for Design Institute of San Diego
# Created 8 rows (years) for DeVry University-California
# Created 17 rows (years) for Diablo Valley College
# Created 12 rows (years) for Dominican University of California
# Created 13 rows (years) for Dominican School of Philosophy & Theology
# Created 0 rows (years) for Don Bosco Technical Institute
# Created 17 rows (years) for East Los Angeles College
# Created 0 rows (years) for Marinello Schools of Beauty-Santa Clara
# Created 16 rows (years) for El Camino Community College District
# Created 0 rows (years) for Elegance International
# Created 0 rows (years) for Marinello Schools of Beauty-City of Industry
# Created 0 rows (years) for Marinello Schools of Beauty-Burbank
# Created 0 rows (years) for Marinello Schools of Beauty-Moreno Valley
# Created 3 rows (years) for Emperor's College of Traditional Oriental Medicine
# Created 11 rows (years) for Empire College
# Created 17 rows (years) for Evergreen Valley College
# Created 0 rows (years) for Spectrum Community Services Inc
# Created 16 rows (years) for FIDM-Fashion Institute of Design & Merchandising-Los Angeles
# Created 0 rows (years) for Fashion Careers College
# Created 14 rows (years) for FIDM-Fashion Institute of Design & Merchandising-San Francisco
# Created 12 rows (years) for FIDM-Fashion Institute of Design & Merchandising-Orange County
# Created 15 rows (years) for Feather River Community College District
# Created 0 rows (years) for Federico Beauty Institute
# Created 17 rows (years) for Fielding Graduate University
# Created 9 rows (years) for Five Branches University
# Created 17 rows (years) for Foothill College
# Created 2 rows (years) for Franciscan School of Theology
# Created 0 rows (years) for Fredrick and Charles Beauty College
# Created 16 rows (years) for Fresno City College
# Created 13 rows (years) for Fresno Pacific University
# Created 1 rows (years) for Foothill-De Anza Community College District
# Created 12 rows (years) for Fuller Theological Seminary
# Created 17 rows (years) for Fullerton College
# Created 0 rows (years) for Galen College of Medical and Dental Assistants
# Created 0 rows (years) for Galen College of Medical and Dental Assistants
# Created 0 rows (years) for Galen College of Medical and Dental Assistants
# Created 15 rows (years) for Gavilan College
# Created 1 rows (years) for Gemological Institute of America-Carlsbad
# Created 16 rows (years) for Glendale Community College
# Created 6 rows (years) for Glendale Career College
# Created 0 rows (years) for Golden Gate Baptist Theological Seminary
# Created 11 rows (years) for Golden Gate University-San Francisco
# Created 16 rows (years) for Golden West College
# Created 12 rows (years) for Graduate Theological Union
# Created 1 rows (years) for Grossmont-Cuyamaca Community College District
# Created 13 rows (years) for Grossmont College
# Created 0 rows (years) for Salon Success Academy-Riverside
# Created 14 rows (years) for Hartnell College
# Created 12 rows (years) for Harvey Mudd College
# Created 6 rows (years) for Heald College-Rancho Cordova
# Created 6 rows (years) for Heald College-Fresno
# Created 6 rows (years) for Heald College-San Jose
# Created 6 rows (years) for Heald College-San Francisco
# Created 6 rows (years) for Heald College-Concord
# Created 0 rows (years) for Hilltop Beauty School
# Created 14 rows (years) for Holy Names University
# Created 11 rows (years) for Pacifica Graduate Institute
# Created 15 rows (years) for Humboldt State University
# Created 15 rows (years) for Humphreys University-Stockton and Modesto Campuses
# Created 16 rows (years) for Imperial Valley College
# Created 5 rows (years) for Institute for Business and Technology
# Created 2 rows (years) for LA College International
# Created 0 rows (years) for Interior Designers Institute
# Created 0 rows (years) for INTERNATIONAL AIR ACADEMY
# Created 0 rows (years) for International School of Cosmetology
# Created 17 rows (years) for Irvine Valley College
# Created 11 rows (years) for ITT Technical Institute-National City
# Created 11 rows (years) for ITT Technical Institute-San Dimas
# Created 11 rows (years) for ITT Technical Institute-Orange
# Created 0 rows (years) for Bellus Academy-El Cajon
# Created 3 rows (years) for Jesuit School of Theology of Santa Clara University
# Created 11 rows (years) for John F. Kennedy University
# Created 11 rows (years) for American Jewish University
# Created 15 rows (years) for Reedley College
# Created 13 rows (years) for Life Pacific University
# Created 9 rows (years) for Argosy University-The Art Institute of California-San Diego
# Created 14 rows (years) for University of La Verne
# Created 12 rows (years) for Laguna College of Art and Design
# Created 0 rows (years) for Lake Forest Beauty College
# Created 17 rows (years) for Lake Tahoe Community College
# Created 0 rows (years) for Lancaster Beauty School
# Created 15 rows (years) for Laney College
# Created 16 rows (years) for Lassen Community College
# Created 13 rows (years) for Life Chiropractic College West
# Created 7 rows (years) for Lincoln University
# Created 11 rows (years) for Southern California Seminary
# Created 13 rows (years) for La Sierra University
# Created 11 rows (years) for Loma Linda University
# Created 17 rows (years) for Long Beach City College
# Created 14 rows (years) for Southern California University of Health Sciences
# Created 11 rows (years) for Los Angeles Community College District Office
# Created 17 rows (years) for Los Angeles Harbor College
# Created 17 rows (years) for Los Angeles Pierce College
# Created 17 rows (years) for Los Angeles Southwest College
# Created 17 rows (years) for Los Angeles Trade Technical College
# Created 17 rows (years) for Los Angeles Valley College
# Created 11 rows (years) for The Master's University and Seminary
# Created 17 rows (years) for Los Angeles City College
# Created 0 rows (years) for Harbor-UCLA Medical Center
# Created 16 rows (years) for Los Angeles County College of Nursing and Allied Health
# Created 17 rows (years) for Los Angeles Mission College
# Created 17 rows (years) for Los Medanos College
# Created 6 rows (years) for Los Rios Community College District Office
# Created 9 rows (years) for Argosy University-The Art Institute of California-San Francisco
# Created 17 rows (years) for Loyola Marymount University
# Created 0 rows (years) for Manchester Beauty College
# Created 0 rows (years) for Tulare Beauty College
# Created 0 rows (years) for Lyle's College of Beauty
# Created 0 rows (years) for Lyle's College of  Beauty
# Created 0 rows (years) for Lytles Redwood Empire Beauty College Inc
# Created 0 rows (years) for MTI Business College Inc
# Created 14 rows (years) for MTI College
# Created 11 rows (years) for Brightwood College-Sacramento
# Created 11 rows (years) for Brightwood College-San Diego
# Created 13 rows (years) for Brightwood College-Vista
# Created 0 rows (years) for Marin Regional Occupational Program
# Created 15 rows (years) for College of Marin
# Created 0 rows (years) for Marinello Schools of Beauty-Los Angeles
# Created 0 rows (years) for Marinello School of Beauty
# Created 0 rows (years) for Marinello School of Beauty
# Created 0 rows (years) for Marinello School of Beauty
# Created 0 rows (years) for Marinello School of Beauty
# Created 0 rows (years) for Marinello School of Beauty
# Created 0 rows (years) for Marinello School of Beauty
# Created 0 rows (years) for Marinello School of Beauty
# Created 0 rows (years) for Marinello School of Beauty
# Created 0 rows (years) for Marinello School of Beauty
# Created 16 rows (years) for Marymount California University
# Created 16 rows (years) for Mendocino College
# Created 12 rows (years) for Menlo College
# Created 3 rows (years) for Mennonite Brethren Biblical Seminary
# Created 16 rows (years) for Merced College
# Created 15 rows (years) for Merritt College
# Created 13 rows (years) for Mills College
# Created 13 rows (years) for MiraCosta College
# Created 0 rows (years) for Marinello Schools of Beauty-San Francisco
# Created 15 rows (years) for Mission College
# Created 0 rows (years) for Modern Beauty Academy
# Created 5 rows (years) for Brightwood College-Los Angeles-Van Nuys
# Created 17 rows (years) for Modesto Junior College
# Created 0 rows (years) for Moler Barber College
# Created 12 rows (years) for Middlebury Institute of International Studies at Monterey
# Created 16 rows (years) for Monterey Peninsula College
# Created 0 rows (years) for MONTESSORI WESTERN TEACHER TRAINING PROGRAM
# Created 17 rows (years) for Moorpark College
# Created 0 rows (years) for MORO BEAUTY COLLEGE
# Created 17 rows (years) for Mt San Antonio College
# Created 13 rows (years) for Mount Saint Mary's University
# Created 13 rows (years) for Mt San Jacinto Community College District
# Created 13 rows (years) for Musicians Institute
# Created 17 rows (years) for Napa Valley College
# Created 0 rows (years) for Everest College-San Francisco
# Created 2 rows (years) for Everest College-Reseda
# Created 3 rows (years) for Everest College-LA Wilshire
# Created 0 rows (years) for Everest College-San Jose
# Created 0 rows (years) for Everest College-Gardena
# Created 0 rows (years) for Everest College-Alhambra
# Created 4 rows (years) for Everest College-San Bernardino
# Created 5 rows (years) for The National Hispanic University
# Created 0 rows (years) for National Holistic Institute
# Created 14 rows (years) for National University
# Created 10 rows (years) for Naval Postgraduate School
# Created 1 rows (years) for New College of California
# Created 13 rows (years) for Newschool of Architecture and Design
# Created 0 rows (years) for Marinello School of Beauty
# Created 0 rows (years) for Newberry School of Beauty
# Created 0 rows (years) for North Adrian's College of Beauty Inc
# Created 0 rows (years) for North Orange County Community College District
# Created 0 rows (years) for North-West College-Pomona
# Created 6 rows (years) for North-West College-West Covina
# Created 0 rows (years) for North-West College-Van Nuys
# Created 8 rows (years) for Northwestern Polytechnic University
# Created 13 rows (years) for Notre Dame de Namur University
# Created 12 rows (years) for Occidental College
# Created 0 rows (years) for Oceanside College of Beauty
# Created 17 rows (years) for Ohlone College
# Created 0 rows (years) for Opportunities Industrialization Center-West
# Created 16 rows (years) for Orange Coast College
# Created 11 rows (years) for Otis College of Art and Design
# Created 17 rows (years) for Oxnard College
# Created 12 rows (years) for Hope International University
# Created 11 rows (years) for Concorde Career College-San Diego
# Created 13 rows (years) for Palo Alto University
# Created 10 rows (years) for Pacific Lutheran Theological Seminary
# Created 16 rows (years) for Pacific Oaks College
# Created 13 rows (years) for Pacific School of Religion
# Created 6 rows (years) for Pacific States University
# Created 14 rows (years) for Pacific Union College
# Created 14 rows (years) for University of the Pacific
# Created 6 rows (years) for Palmer College of Chiropractic-San Jose
# Created 15 rows (years) for Palo Verde College
# Created 17 rows (years) for Palomar College
# Created 0 rows (years) for Marinello Schools of Beauty-Paramount
# Created 0 rows (years) for Paris Beauty College
# Created 15 rows (years) for Pasadena City College
# Created 4 rows (years) for Patten University
# Created 15 rows (years) for Pepperdine University
# Created 8 rows (years) for Peralta Community College System Office
# Created 14 rows (years) for Pitzer College
# Created 14 rows (years) for Platt College-San Diego
# Created 14 rows (years) for Point Loma Nazarene University
# Created 17 rows (years) for Pomona College
# Created 17 rows (years) for Porterville College
# Created 7 rows (years) for Westwood College-South Bay
# Created 0 rows (years) for Professional Institute of Beauty
# Created 0 rows (years) for Larei
# Created 17 rows (years) for Santa Ana College
# Created 0 rows (years) for Pardee RAND Graduate School
# Created 13 rows (years) for University of Redlands
# Created 14 rows (years) for College of the Redwoods
# Created 0 rows (years) for Salon Success Academy-Upland
# Created 0 rows (years) for Salon Success Academy-Corona
# Created 17 rows (years) for Rio Hondo College
# Created 17 rows (years) for Riverside City College
# Created 11 rows (years) for Argosy University-San Francisco Bay Area
# Created 0 rows (years) for Rosemead Beauty School
# Created 6 rows (years) for Dongguk University Los Angeles
# Created 17 rows (years) for Sacramento City College
# Created 17 rows (years) for Saddleback College
# Created 0 rows (years) for St Johns Seminary College
# Created 1 rows (years) for Saint Patrick's Seminary and University
# Created 2 rows (years) for Samra University of Oriental Medicine
# Created 17 rows (years) for Samuel Merritt University
# Created 7 rows (years) for San Diego Community College District-District Office
# Created 17 rows (years) for San Diego City College
# Created 5 rows (years) for Golf Academy of America-San Diego
# Created 17 rows (years) for San Diego Mesa College
# Created 17 rows (years) for San Diego Miramar College
# Created 15 rows (years) for San Diego State University
# Created 17 rows (years) for University of San Diego
# Created 13 rows (years) for San Francisco Art Institute
# Created 17 rows (years) for San Francisco Conservatory of Music
# Created 15 rows (years) for San Francisco State University
# Created 9 rows (years) for University of Redlands Graduate School of Theology
# Created 17 rows (years) for University of San Francisco
# Created 15 rows (years) for San Joaquin College of Law
# Created 16 rows (years) for San Joaquin Delta College
# Created 0 rows (years) for SAN JOAQUIN GENERAL HOSPITAL SCHOOL OF RAD TECHN
# Created 13 rows (years) for San Joaquin Valley College-Visalia
# Created 8 rows (years) for San Joaquin Valley College-Bakersfield
# Created 14 rows (years) for William Jessup University
# Created 0 rows (years) for San Jose-Evergreen Community College District
# Created 17 rows (years) for San Jose City College
# Created 15 rows (years) for San Jose State University
# Created 2 rows (years) for San Mateo County Community College District Office
# Created 14 rows (years) for College of San Mateo
# Created 11 rows (years) for Santa Barbara Business College-Bakersfield
# Created 9 rows (years) for Westwood College-Los Angeles
# Created 4 rows (years) for Santa Barbara Business College-Santa Maria
# Created 15 rows (years) for Santa Barbara City College
# Created 17 rows (years) for Santa Clara University
# Created 14 rows (years) for Santa Monica College
# Created 16 rows (years) for Santa Rosa Junior College
# Created 11 rows (years) for Saybrook University
# Created 16 rows (years) for Scripps College
# Created 5 rows (years) for Wyotech-Fremont
# Created 16 rows (years) for College of the Sequoias
# Created 1 rows (years) for Shasta Bible College and Graduate School
# Created 16 rows (years) for Shasta College
# Created 16 rows (years) for Sierra College
# Created 0 rows (years) for Sierra College of Beauty
# Created 0 rows (years) for Sierra Valley College of Court Reporting
# Created 9 rows (years) for Trinity Law School
# Created 13 rows (years) for Simpson University
# Created 17 rows (years) for College of the Siskiyous
# Created 0 rows (years) for Charles A Jones Career and Education Center
# Created 16 rows (years) for Skyline College
# Created 13 rows (years) for San Bernardino Valley College
# Created 17 rows (years) for Saint Mary's College of California
# Created 17 rows (years) for Solano Community College
# Created 15 rows (years) for Sonoma State University
# Created 4 rows (years) for Pinnacle College
# Created 11 rows (years) for South Baylo University
# Created 5 rows (years) for South Coast College
# Created 12 rows (years) for Vanguard University of Southern California
# Created 12 rows (years) for Concorde Career College-Garden Grove
# Created 17 rows (years) for Southwestern College
# Created 10 rows (years) for St John's Seminary
# Created 5 rows (years) for Starr King School for the Ministry
# Created 0 rows (years) for State Center Community College District
# Created 14 rows (years) for Marshall B Ketchum University
# Created 12 rows (years) for Southern California Institute of Architecture
# Created 17 rows (years) for University of Southern California
# Created 12 rows (years) for Southwestern Law School
# Created 17 rows (years) for Taft College
# Created 14 rows (years) for Claremont School of Theology
# Created 14 rows (years) for Thomas Aquinas College
# Created 0 rows (years) for Marinello Schools of Beauty-Lake Forest
# Created 0 rows (years) for Travel and Trade Career Institute
# Created 0 rows (years) for TRAVEL UNIVERSITY INTERNATIONAL
# Created 9 rows (years) for Epic Bible College
# Created 15 rows (years) for University of California-System Administration Central Office
# Created 2 rows (years) for United Education Institute-Huntington Park Campus
# Created 12 rows (years) for Concorde Career College-San Bernardino
# Created 0 rows (years) for Universal College of Beauty Inc-Los Angeles 1
# Created 0 rows (years) for Vallecitos CET Inc
# Created 12 rows (years) for Concorde Career College-North Hollywood
# Created 0 rows (years) for Ventura County Community College System Office
# Created 17 rows (years) for Ventura College
# Created 0 rows (years) for Bridges Beauty College
# Created 15 rows (years) for Victor Valley College
# Created 15 rows (years) for Berkeley City College
# Created 0 rows (years) for West Valley Mission Community College District Office
# Created 11 rows (years) for Walden University
# Created 15 rows (years) for West Hills College-Coalinga
# Created 17 rows (years) for West Los Angeles College
# Created 3 rows (years) for The University of West Los Angeles
# Created 16 rows (years) for West Valley College
# Created 15 rows (years) for Carrington College-Sacramento
# Created 11 rows (years) for Westminster Theological Seminary in California
# Created 17 rows (years) for Westmont College
# Created 13 rows (years) for Whittier College
# Created 11 rows (years) for Woodbury University
# Created 12 rows (years) for The Wright Institute
# Created 13 rows (years) for Western State College of Law at Argosy University
# Created 14 rows (years) for Thomas Jefferson School of Law
# Created 3 rows (years) for Yeshiva Ohr Elchonon Chabad West Coast Talmudical Seminary
# Created 7 rows (years) for Yosemite Community College District Office
# Created 17 rows (years) for Yuba College
# Created 0 rows (years) for The Salon Professional Academy-Grand Junction
# Created 16 rows (years) for Adams State University
# Created 17 rows (years) for Aims Community College
# Created 0 rows (years) for Bluffs Academy Inc
# Created 15 rows (years) for Arapahoe Community College
# Created 11 rows (years) for Bel-Rea Institute of Animal Technology
# Created 6 rows (years) for Altierus Career College-Colorado Springs
# Created 1 rows (years) for Boulder College of Massage Therapy
# Created 17 rows (years) for University of Colorado Denver/Anschutz Medical Campus
# Created 1 rows (years) for University of Colorado Health Sciences Center
# Created 15 rows (years) for University of Colorado Colorado Springs
# Created 12 rows (years) for Spartan College of Aeronautics and Technology
# Created 15 rows (years) for University of Colorado Boulder
# Created 12 rows (years) for Colorado Christian University
# Created 14 rows (years) for Colorado College
# Created 12 rows (years) for Concorde Career College-Aurora
# Created 9 rows (years) for The Art Institute of Colorado
# Created 16 rows (years) for Colorado Mountain College
# Created 14 rows (years) for Colorado Northwestern Community College
# Created 15 rows (years) for Colorado School of Mines
# Created 10 rows (years) for Colorado School of Trades
# Created 16 rows (years) for Colorado State University-Fort Collins
# Created 16 rows (years) for Colorado Technical University-Colorado Springs
# Created 0 rows (years) for Empire Beauty School-Lakewood
# Created 13 rows (years) for Community College of Aurora
# Created 11 rows (years) for CollegeAmerica-Denver
# Created 0 rows (years) for Technical College of the Rockies
# Created 4 rows (years) for Prince Institute-Rocky Mountains
# Created 17 rows (years) for Community College of Denver
# Created 13 rows (years) for Lincoln College of Technology-Denver
# Created 12 rows (years) for Denver Seminary
# Created 7 rows (years) for Westwood College-Denver North
# Created 16 rows (years) for University of Denver
# Created 0 rows (years) for Emily Griffith Technical College
# Created 16 rows (years) for Fort Lewis College
# Created 12 rows (years) for Front Range Community College
# Created 0 rows (years) for Glenwood Beauty Academy
# Created 0 rows (years) for Hair Dynamics Education Center
# Created 14 rows (years) for Iliff School of Theology
# Created 0 rows (years) for International Salon and Spa Academy
# Created 14 rows (years) for Lamar Community College
# Created 14 rows (years) for Colorado Mesa University
# Created 16 rows (years) for Metropolitan State University of Denver
# Created 16 rows (years) for Morgan Community College
# Created 16 rows (years) for Naropa University
# Created 2 rows (years) for National American University-Colorado Springs
# Created 5 rows (years) for National American University-Denver
# Created 15 rows (years) for Nazarene Bible College
# Created 14 rows (years) for Northeastern Junior College
# Created 16 rows (years) for University of Northern Colorado
# Created 15 rows (years) for Otero Junior College
# Created 7 rows (years) for Altierus Career College-Thornton
# Created 14 rows (years) for Pikes Peak Community College
# Created 7 rows (years) for IBMC College
# Created 14 rows (years) for Pueblo Community College
# Created 16 rows (years) for Red Rocks Community College
# Created 12 rows (years) for Regis University
# Created 12 rows (years) for Rocky Mountain College of Art and Design
# Created 0 rows (years) for Montessori Education Center of the Rockies
# Created 0 rows (years) for San Juan Basin Technical College
# Created 12 rows (years) for Colorado State University Pueblo
# Created 0 rows (years) for Pickens Technical College
# Created 13 rows (years) for Intellitec College-Colorado Springs
# Created 14 rows (years) for Intellitec College-Grand Junction
# Created 0 rows (years) for Artistic Beauty Colleges-Westminster
# Created 13 rows (years) for Trinidad State Junior College
# Created 0 rows (years) for University of Colorado System Office
# Created 14 rows (years) for United States Air Force Academy
# Created 0 rows (years) for Empire Beauty School-Thornton
# Created 13 rows (years) for Western Colorado University
# Created 0 rows (years) for Yeshiva Toras Chaim Talmudical Seminary
# Created 11 rows (years) for Albertus Magnus College
# Created 0 rows (years) for Paul Mitchell the School-Danbury
# Created 14 rows (years) for Asnuntuck Community College
# Created 0 rows (years) for Bais Binyomin Academy
# Created 0 rows (years) for Branford Hall Career Institute-Branford Campus
# Created 10 rows (years) for Lincoln College of New England-Southington
# Created 0 rows (years) for Bridgeport Hospital School of Nursing
# Created 14 rows (years) for University of Bridgeport
# Created 0 rows (years) for Butler Business School Inc
# Created 14 rows (years) for Central Connecticut State University
# Created 0 rows (years) for Charter Oak State College
# Created 0 rows (years) for Cortiva Institute-Cromwell
# Created 11 rows (years) for Connecticut College
# Created 0 rows (years) for Marinello Schools of Beauty-East Hartford
# Created 0 rows (years) for Porter and Chester Institute of Hamden
# Created 13 rows (years) for University of Connecticut
# Created 14 rows (years) for Goodwin University
# Created 0 rows (years) for Lincoln Technical Institute-East Windsor
# Created 13 rows (years) for Eastern Connecticut State University
# Created 11 rows (years) for Fairfield University
# Created 0 rows (years) for Paul Mitchell the School-North Haven
# Created 13 rows (years) for Capital Community College
# Created 8 rows (years) for Rensselaer at Hartford
# Created 0 rows (years) for Hartford School of Music
# Created 0 rows (years) for American Institute-West Hartford
# Created 11 rows (years) for Hartford Seminary
# Created 12 rows (years) for University of Hartford
# Created 12 rows (years) for Holy Apostles College and Seminary
# Created 13 rows (years) for Housatonic Community College
# Created 7 rows (years) for Sanford-Brown College-Farmington
# Created 0 rows (years) for The Leon Institute of Hair Design
# Created 5 rows (years) for Lyme Academy College of Fine Arts
# Created 13 rows (years) for Manchester Community College
# Created 13 rows (years) for Naugatuck Valley Community College
# Created 12 rows (years) for Middlesex Community College
# Created 12 rows (years) for Mitchell College
# Created 13 rows (years) for Three Rivers Community College
# Created 0 rows (years) for Renasci Academy of Hair Inc
# Created 0 rows (years) for Lincoln Technical Institute-New Britain
# Created 0 rows (years) for New England Tractor Trailer Training School of Connecticut
# Created 12 rows (years) for University of New Haven
# Created 0 rows (years) for Ridley-Lowell Business & Technical Institute-New London
# Created 14 rows (years) for Norwalk Community College
# Created 13 rows (years) for Northwestern Connecticut Community College
# Created 10 rows (years) for Paier College of Art Inc
# Created 0 rows (years) for Marinello Schools of Beauty-Meriden
# Created 0 rows (years) for Porter and Chester Institute of Stratford
# Created 13 rows (years) for Post University
# Created 12 rows (years) for Quinebaug Valley Community College
# Created 12 rows (years) for Quinnipiac University
# Created 12 rows (years) for Sacred Heart University
# Created 0 rows (years) for St Basil College
# Created 12 rows (years) for University of Saint Joseph
# Created 13 rows (years) for Gateway Community College
# Created 9 rows (years) for St Vincent's College
# Created 13 rows (years) for Southern Connecticut State University
# Created 0 rows (years) for Stone Academy-West Haven
# Created 4 rows (years) for Tri-State College of Acupuncture
# Created 11 rows (years) for Trinity College
# Created 13 rows (years) for Tunxis Community College
# Created 11 rows (years) for United States Coast Guard Academy
# Created 13 rows (years) for Wesleyan University
# Created 14 rows (years) for Western Connecticut State University
# Created 0 rows (years) for Yale-New Haven Hospital Dietetic Internship
# Created 13 rows (years) for Yale University
# Created 0 rows (years) for Margaret H Rollins School of Nursing at Beebe Medical Center
# Created 0 rows (years) for Dawn Career Institute LLC
# Created 3 rows (years) for Delaware Technical Community College-Central Office
# Created 10 rows (years) for Delaware Technical Community College-Owens
# Created 16 rows (years) for Delaware Technical Community College-Terry
# Created 10 rows (years) for Delaware Technical Community College-Stanton/Wilmington
# Created 15 rows (years) for Delaware State University
# Created 16 rows (years) for University of Delaware
# Created 15 rows (years) for Goldey-Beacom College
# Created 0 rows (years) for Schilling-Douglas School of Hair Design LLC
# Created 14 rows (years) for Wesley College
# Created 14 rows (years) for Wilmington University
# Created 13 rows (years) for American University
# Created 11 rows (years) for The Catholic University of America
# Created 6 rows (years) for Corcoran College of Art and Design
# Created 13 rows (years) for University of the District of Columbia
# Created 12 rows (years) for Pontifical Faculty of the Immaculate Conception at the Dominican House of Studies
# Created 11 rows (years) for Gallaudet University
# ...
# Created 0 rows (years) for Relay Graduate School of Education - California
# Created 0 rows (years) for WellSpring School of Allied Health-Springfield
# Created 0 rows (years) for Southeastern College-Miami Lakes
# Created 0 rows (years) for Haven University
# Created 0 rows (years) for Stockton Christian Life College
# Created 0 rows (years) for Vaughn Beauty College
# Created 1 rows (years) for Southeastern Free Will Baptist Bible College
# Created 2 rows (years) for Albert Einstein College of Medicine
# Created 0 rows (years) for Los Angeles Pacific College
# Created 0 rows (years) for Minnesota State Colleges and Universities System Office
# Created 2 rows (years) for American College of the Building Arts
# Created 1 rows (years) for Maine Media College
# Created 0 rows (years) for D&S School of Cosmetology
# Created 0 rows (years) for Houston School of Carpentry
# Created 0 rows (years) for GoodFellas Barber College
# Created 0 rows (years) for Medical Career College of Northern California
# Created 0 rows (years) for Premiere International College
# Created 0 rows (years) for Kenny's Beauty Academy
# Created 0 rows (years) for American Fitness and Nutrition Academy
# Created 0 rows (years) for San Diego Global Knowledge University
# Created 0 rows (years) for Global Tech College
# Created 0 rows (years) for Bristol School of Hair Design
# Created 0 rows (years) for MCI
# Created 0 rows (years) for Central Pennsylvania Diesel Institute
# Created 0 rows (years) for Bellasa Professional Institute
# Created 0 rows (years) for PMCA Pittsburgh Multicultural Cosmetology Academy
# Created 0 rows (years) for Health and Technology Training Institute
# Created 0 rows (years) for Yeshiva of Ocean
# Created 2 rows (years) for Congregation Talmidei Mesivta Tiferes Shmiel Aleksander
# Created 1 rows (years) for Young Americans College of the Performing Arts
# Created 0 rows (years) for Pro Beauty Academy
# Created 0 rows (years) for South Eastern Beauty Academy
# Created 2 rows (years) for Ohel Margulia Seminary
# Created 0 rows (years) for Montana Barber Institute
# Created 0 rows (years) for Yeshivat Hechal Shemuel
# Created 0 rows (years) for Puerto Rico School of Nurse Anesthetists
# Created 0 rows (years) for American Institute of Healthcare & Technology
# Created 0 rows (years) for Premier Academy of Cosmetology
# Created 0 rows (years) for Yeshiva Gedolah of Woodlake Village
# Created 0 rows (years) for Yeshiva Gedola Tiferes Yaakov Yitzchok
# Created 0 rows (years) for University of Arkansas System eVersity
# Created 0 rows (years) for Careers Institute of America
# Created 0 rows (years) for Houston Barber School
# Created 0 rows (years) for Health-Tech Institute of Memphis
# Created 0 rows (years) for MIXED Institute of Cosmetology & Barber
# Created 0 rows (years) for Vski Cosmetology School
# Created 0 rows (years) for Shear Perfection Academy of Cosmetology
# Created 0 rows (years) for New York Seminary
# Created 0 rows (years) for Deluxe Barber College
# Created 0 rows (years) for Falcon Institute of Health and Science
# Created 0 rows (years) for College Unbound
# Created 0 rows (years) for Midwest Barber College
# Created 0 rows (years) for SANS Technology Institute
# Created 0 rows (years) for Tuana European Beauty Academy
# Created 2 rows (years) for Idaho College of Osteopathic Medicine
# Created 0 rows (years) for Southern Careers Institute-Waco
# Created 0 rows (years) for Elevate Salon Institute
# Created 1 rows (years) for Ponce Health Sciences University-St Louis
# Created 0 rows (years) for Lil Lou's Beauty and Barber College-Hammond
# Created 0 rows (years) for Indiana Wesleyan University - Marion Design Co.
# Created 0 rows (years) for High Desert Medical College - Temecula
# Created 0 rows (years) for Columbia College - Waynesville
# Created 0 rows (years) for Columbia College - Naval Base San Diego
# Created 0 rows (years) for Columbia College - Imperial
# Created 0 rows (years) for Columbia College - NSB Kings Bay
# Created 0 rows (years) for Columbia College - Waynesville
# Created 2 rows (years) for Arizona College-Dallas
# Created 2 rows (years) for Arizona College of Nursing-Tempe
# Created 0 rows (years) for Miami Lakes Educational Center and Technical College -
# Created 0 rows (years) for University of Oklahoma - Nellis Air Force Base
# Created 0 rows (years) for The Salon Professional Academy-Washington DC
# Created 0 rows (years) for Old Town Barber College - KC
# Created 1 rows (years) for Valley College-Cleveland
# Created 0 rows (years) for National American University-Kings Bay
# Created 2 rows (years) for EDP University of Puerto Rico-Humacao
# Created 2 rows (years) for EDP University of Puerto Rico-Manati
# Created 0 rows (years) for Relay Graduate School of Education - Indiana
# Created 0 rows (years) for Hillsdale Beauty College
# Created 0 rows (years) for Leston College -
# Created 0 rows (years) for Southern California Health Institute (SOCHI) - North Hollywood
# Created 0 rows (years) for Aviator College of Aeronautical Science & Technology - Kissimmee
# Created 0 rows (years) for UEI College-Sacramento
# Created 0 rows (years) for Strayer University - Montgomery Campus
# Created 0 rows (years) for Strayer University - Decatur Campus
# Created 0 rows (years) for Thomas Aquinas College - New England
# Created 0 rows (years) for Universal Spa Training Academy - Tyler's Beauty and Spa Academy
# Created 0 rows (years) for Porter and Chester Institute - New London
# Created 0 rows (years) for Advanced College - Salida
# Created 2 rows (years) for Fortis Institute-Cookeville
# Created 0 rows (years) for Paul Mitchell the School-San Jose
# Created 0 rows (years) for Derech Hachaim Seminary
# Created 0 rows (years) for Arizona State University - Yavapai College Prescott Valley Campus
# Created 0 rows (years) for Arizona State University - Pima
# Created 0 rows (years) for Avenue Five Institute-South Austin Campus
# Created 0 rows (years) for Glasgow Caledonian New York College
# Created 0 rows (years) for Guidance College
# Created 0 rows (years) for Universal Trinity College
# Created 1 rows (years) for Pima Medical Institute-San Antonio
# Created 0 rows (years) for Faith Theological Seminary and Christian College
# Created 0 rows (years) for Southwestern Baptist Theological Seminary
# Created 0 rows (years) for Lotus School of Integrated Professions
# Created 0 rows (years) for Christ Mission College
# Created 0 rows (years) for Esteem Academy of Beauty
# Created 0 rows (years) for KC Beauty Academy
# Created 0 rows (years) for Urshan College
# Created 0 rows (years) for Texas Healthtech Institute
# Created 0 rows (years) for Xtylo Beauty College
# Created 0 rows (years) for Tonsorial Arts Barber College
# Created 0 rows (years) for Michael's Barber & Hair Stylist Academy
# Created 2 rows (years) for Yeshiva Yesoda Hatorah Vetz Chaim
# Created 1 rows (years) for Glendale Career College-Brightwood Teachout
# Created 0 rows (years) for West Virginia Junior College-United Career Institute
# Created 0 rows (years) for Aviation Institute of Maintenance-Charlotte
# Created 0 rows (years) for Dayton School of Medical Massage - Columbus School of Medical Massage
# Created 0 rows (years) for Davenport University - Detroit
# Created 0 rows (years) for Ponce Health Sciences University-East
# Created 0 rows (years) for Urban Barber College - San Jose
# Created 0 rows (years) for Cinta Aveda Institute - San Jose
# Created 0 rows (years) for Educational Technical College
# Created 2 rows (years) for Fortis College-Landover
# Created 2 rows (years) for Stautzenberger College-Rockford Career College
# Created 0 rows (years) for CUNY Brooklyn College - Feirstein Graduate School of Cinema
# Created 0 rows (years) for Rabbinical Seminary of America - Ma'yan HaTorah
# Created 0 rows (years) for Baker College - Flint
# Created 0 rows (years) for WellSpring School of Allied Health-Wichita
# Created 0 rows (years) for Access Careers-Islandia
# Created 0 rows (years) for Franciscan School of Theology - San Diego
# Created 0 rows (years) for University of Montana (The) - Bitterroot College University of Montana
# Created 0 rows (years) for Latin American Bible Institute
# Created 0 rows (years) for San Joaquin Valley College-Hanford Classroom
# Created 0 rows (years) for Commercial Divers International
# Created 0 rows (years) for A Better U Beauty Barber Academy
# Created 0 rows (years) for Evvaylois Academy School of Beauty
# Created 0 rows (years) for California Arts University
# Created 1 rows (years) for Northern Pennsylvania Regional College
# Created 0 rows (years) for American Medical Institute Inc.
# Created 0 rows (years) for Apex College of Veterinary Technology
# Created 0 rows (years) for Meryma'at Barber College
# Created 0 rows (years) for Western Maricopa Education Center
# Created 0 rows (years) for Bais Medrash of Dexter Park
# Created 0 rows (years) for Makana Esthetics Wellness Academy
# Created 0 rows (years) for Oak Valley College
# Created 0 rows (years) for Paul Mitchell the School-San Jose
# Created 0 rows (years) for Zion Massage College
# Created 0 rows (years) for Great Lakes Boat Building School
# Created 0 rows (years) for Austin Career Institute
# Created 0 rows (years) for Professional Culinary Academy
# Created 0 rows (years) for Gather 4 Him Christian College
# Created 0 rows (years) for Altura College
# Created 0 rows (years) for Royal Learning Institute
# Created 0 rows (years) for Hollywood Cultural College
# Created 0 rows (years) for Mariano Moreno Culinary Institute
# Created 1 rows (years) for Alder Graduate School of Education
# Created 0 rows (years) for Webb's Barber School of Arts
# Created 0 rows (years) for Adrian H. Wallace Barber Academy
# Created 0 rows (years) for St. Louis Med Tech
# Created 0 rows (years) for Total Beauty Institute
# Created 0 rows (years) for Pearlands Innovative School of Beauty
# Created 0 rows (years) for Durant Institute of Hair Design
# Created 0 rows (years) for Premiere Aesthetics Institute
# Created 0 rows (years) for California Indian Nations College
# Created 0 rows (years) for Indian Bible College
# Created 0 rows (years) for Florida Professional Institute
# Created 0 rows (years) for The Professional Cosmetology Academy
# Created 1 rows (years) for Hackensack Meridian School of Medicine
# Created 0 rows (years) for BFF Kidz Training
# Created 0 rows (years) for Victor Valley Community College - Aviation Technology
# Created 0 rows (years) for Taylor Andrews Academy of Hair Design-Hair Lab Detroit Barber School
# Created 0 rows (years) for Paul Mitchell the School-Reno-North Tahoe
# Created 0 rows (years) for Paul Mitchell the School-Fort Lauderdale
# Created 0 rows (years) for PCI Academy-Iowa City
# Created 0 rows (years) for Larry's Barber College
# Created 0 rows (years) for Royal Learning Institute
# Created 0 rows (years) for Paul Mitchell the School-Richland-Provo
# Created 0 rows (years) for Arizona College of Nursing-Tampa
# Created 0 rows (years) for Arizona College of Nursing-Fort Lauderdale
# Created 1 rows (years) for Arizona College of Nursing-Tucson
# Created 0 rows (years) for Arizona College of Nursing-Phoenix
# Created 0 rows (years) for Jersey College
# Created 0 rows (years) for Jersey College -
# Created 0 rows (years) for Jersey College
# Created 0 rows (years) for Jersey College -
# Created 0 rows (years) for Jersey College -
# Created 0 rows (years) for Empire Beauty School-Newport News
# Created 0 rows (years) for Western Maricopa Education Center - Southwest Campus
# Created 0 rows (years) for Western Maricopa Education Center - Northeast Campus
# Created 0 rows (years) for National University College - Pembroke Pines
# Created 0 rows (years) for NUC University - Florida Technical College - Lakeland
# Created 0 rows (years) for NUC University - Florida Technical College - Deland
# Created 0 rows (years) for NUC University - Florida Technical College - Kissimmee
# Created 0 rows (years) for NUC University - Florida Technical College - Pembroke Pines
# Created 0 rows (years) for NUC University - Florida Technical College - Cutler Bay
# Created 0 rows (years) for NUC University - IBC Institute - Ponce
# Created 0 rows (years) for NUC University - IBC Institute - Mayag?ez
# Created 0 rows (years) for NUC University - IBC Institute - Guayama
# Created 0 rows (years) for NUC University - IBC Institute - Fajardo
# Created 0 rows (years) for NUC University - IBC Institute - Manat?
# Created 0 rows (years) for NUC University - IBC Institute - Los Colobos
# Created 0 rows (years) for NUC University - IBC Institute - Moca
# Created 0 rows (years) for NUC University - IBC Institute - Aguadilla
# Created 0 rows (years) for NUC University - IBC Institute - Caguas
# Created 0 rows (years) for NUC University - IBC Institute - Arecibo
# Created 0 rows (years) for NUC University - IBC Institute - Escorial
# Created 0 rows (years) for NUC University - IBC Institute - Bayam?n
# Created 0 rows (years) for NUC University - IBC Institute - Yauco
# Created 0 rows (years) for Tricoci University of Beauty Culture-Normal
# Created 0 rows (years) for NUC University - Florida Technical College - Orlando
# Created 0 rows (years) for University of West Los Angeles - Chatsworth
# Created 1 rows (years) for The Pennsylvania State University
# Created 0 rows (years) for Elite Welding Academy
# Created 0 rows (years) for Paul Mitchell the School-Murfreesboro-Nashville
# Created 0 rows (years) for Aveda Institute Des Moines - Aveda Institute Rochester
# Created 0 rows (years) for MAK Beauty Institute - Duluth
# Created 0 rows (years) for Arizona State University - Washington Center
# Created 0 rows (years) for Dorsey School of Business-Woodhaven Campus
# Created 0 rows (years) for Stellar Career College - Chicago, IL
# Created 0 rows (years) for Moody Bible Institute - Spokane
# Created 0 rows (years) for Liberty Junior College - DBA Liberty Technical Institute
# Created 0 rows (years) for Pathways College
# Created 0 rows (years) for San Joaquin Valley College-Madera
# Created 0 rows (years) for San Joaquin Valley College-Delano
# Created 0 rows (years) for San Joaquin Valley College-Atascadero
# Created 0 rows (years) for San Joaquin Valley College-Rancho Mirage
# Created 0 rows (years) for San Joaquin Valley College-Santa Maria
# Created 0 rows (years) for Advantage Technical College-Aguadilla
# Created 0 rows (years) for Porter and Chester Institute - Brockton
# Created 0 rows (years) for San Joaquin Valley College-Porterville
# Created 0 rows (years) for Networks Barber College
# Created 0 rows (years) for Networks Barber College
# Created 1 rows (years) for California University of Science and Medicine
# Created 0 rows (years) for Ruben's Five Star Academy
# Created 0 rows (years) for Mason Anthony School of Cosmetology Arts & Sciences
# Created 0 rows (years) for Cyrus The Great International Online University
# Created 0 rows (years) for San Jacinto Community College District - Generation Park Campus
# Created 0 rows (years) for American College of Barbering - Murfreesboro,TN
# Created 0 rows (years) for Austin Presbyterian Theological Seminary- YMCA Outdoor Center
# Created 0 rows (years) for California Institute of Arts & Technology-National City
# Created 0 rows (years) for Suncoast Technical Education Center -
# Created 0 rows (years) for Columbia College - Minot AFB
# Created 0 rows (years) for Columbia College - Springfield TMobile
# Created 0 rows (years) for Columbia College - Eastfield Pleasant Grove
# Created 0 rows (years) for Columbia College - Fort Leonard Wood 58th Trans BN
# Created 0 rows (years) for Columbia College - USCG Base Honolulu
# Created 0 rows (years) for Columbia College - Tavares PD
# Created 0 rows (years) for Triangle Tech-Chambersburg
# Created 0 rows (years) for Calvin University - Handlon Campus
# Created 0 rows (years) for Provo College-Idaho Falls Campus
# Created 0 rows (years) for Platt College-Miller-Motte College-Chattanooga 2
# Created 0 rows (years) for Digital Film Academy - Atlanta
# Created 1 rows (years) for Eagle Gate College-Boise Campus
# Created 0 rows (years) for Coastline Beauty College - Hemet
# Created 0 rows (years) for Elite Welding Academy
# Created 0 rows (years) for Medspa Academies - NIMA National Institute of Modern Aesthetics
# Created 0 rows (years) for TechSherpas 365
# Created 0 rows (years) for Zorganics Institute Beauty and Wellness

# %%
## List included institutions and how many rows were included
#included_institutions

# %% [markdown]
# ### Validate Sums for institution Records

# %%
## if there are no errors, then the records add up
for record in all_institution_records:
    if(record['tenured_Grand_total_men'] is not None and
       record['tenured_Grand_total_women'] is not None):
        
        assert record['tenured_Grand_total_men'] + record['tenured_Grand_total_women'] == record['tenured_Grand_total']

        if(record['non_tenured_Grand_total'] is not None):
            assert record['tenured_un_tenured_Grand_total'] == record['non_tenured_Grand_total'] + record['tenured_Grand_total'] 
            assert record['non_tenured_Grand_total_men'] + record['non_tenured_Grand_total_women'] == record['non_tenured_Grand_total']
        elif(record['un_tenured_Grand_total'] is not None): 
            assert record['tenured_un_tenured_Grand_total'] == record['un_tenured_Grand_total'] + record['tenured_Grand_total'] 
            assert record['un_tenured_Grand_total_men'] + record['un_tenured_Grand_total_women'] == record['un_tenured_Grand_total']

print("Validated successfully")
# Out:
# Validated successfully

# %% [markdown]
# # Load and Merge Carnegie Categories
#
# * [Documentation on Carnegie Classification](https://carnegieclassifications.iu.edu/classification_descriptions/basic.php)
# * Column explanations and data codes are available in the data_path folder in `CCIHE2018-PublicData.xlsx`
#
# #### Meaning of the BASIC2018 codes:
# * 1	Associate's Colleges: High Transfer-High Traditional
# * 2	Associate's Colleges: High Transfer-Mixed Traditional/Nontraditional
# * 3	Associate's Colleges: High Transfer-High Nontraditional
# * 4	Associate's Colleges: Mixed Transfer/Career & Technical-High Traditional
# * 5	Associate's Colleges: Mixed Transfer/Career & Technical-Mixed Traditional/Nontraditional
# * 6	Associate's Colleges: Mixed Transfer/Career & Technical-High Nontraditional
# * 7	Associate's Colleges: High Career & Technical-High Traditional
# * 8	Associate's Colleges: High Career & Technical-Mixed Traditional/Nontraditional
# * 9	Associate's Colleges: High Career & Technical-High Nontraditional
# * 10	Special Focus Two-Year: Health Professions
# * 11	Special Focus Two-Year: Technical Professions
# * 12	Special Focus Two-Year: Arts & Design
# * 13	Special Focus Two-Year: Other Fields
# * 14	Baccalaureate/Associate's Colleges: Associate's Dominant
# * 15	Doctoral Universities: Very High Research Activity
# * 16	Doctoral Universities: High Research Activity
# * 17	Doctoral/Professional Universities
# * 18	Master's Colleges & Universities: Larger Programs
# * 19	Master's Colleges & Universities: Medium Programs
# * 20	Master's Colleges & Universities: Small Programs
# * 21	Baccalaureate Colleges: Arts & Sciences Focus
# * 22	Baccalaureate Colleges: Diverse Fields
# * 23	Baccalaureate/Associate's Colleges: Mixed Baccalaureate/Associate's
# * 24	Special Focus Four-Year: Faith-Related Institutions
# * 25	Special Focus Four-Year: Medical Schools & Centers
# * 26	Special Focus Four-Year: Other Health Professions Schools
# * 27	Special Focus Four-Year: Engineering Schools
# * 28	Special Focus Four-Year: Other Technology-Related Schools
# * 29	Special Focus Four-Year: Business & Management Schools
# * 30	Special Focus Four-Year: Arts, Music & *  Schools
# * 31	Special Focus Four-Year: Law Schools
# * 32	Special Focus Four-Year: Other Special Focus Institutions
# * 33	Tribal Colleges

# %%
important_columns = [
    "UNITID", # IPEDS ID
    "HBCU", #historically black college/university
    "HSI ",  #hispanic-serving institution
    "TRIBAL",
    "BASIC2018"
]

carnegie_categories = {}
with codecs.open(data_path + "CCIHE2018-PublicData.csv", encoding='utf-8-sig') as f:
    for row in csv.DictReader(f):
        new_row = {}
        for col in important_columns:
            #strip the new col since HSI has an extra space in the Carnegie data
            #and I don't want to pass on the missing space
            new_row[col.strip()] = row[col] 
        carnegie_categories[row['UNITID']] = new_row

# %% [markdown]
# ### Merge In Carnegie Categories by Row

# %%
for record in all_institution_records:
    unitid = record['UNITID']
    if unitid in carnegie_categories.keys():
        carnegie_row = carnegie_categories[unitid]
    else:
        carnegie_row = {"BASIC2018": None, "HBCU":None, "HSI":None, "TRIBAL":None}
    for col in carnegie_row.keys():
        record[col] = carnegie_row[col]

# %%
Counter([x['BASIC2018'] for x in all_institution_records])
# Out:
# Counter({'18': 4953,
#          '15': 2046,
#          '20': 1802,
#          '16': 2048,
#          '19': 2692,
#          None: 6334,
#          '2': 1768,
#          '22': 4122,
#          '21': 3260,
#          '1': 1795,
#          '23': 1671,
#          '5': 1538,
#          '7': 1577,
#          '24': 2400,
#          '8': 1212,
#          '4': 1807,
#          '17': 2081,
#          '32': 256,
#          '13': 373,
#          '10': 1945,
#          '26': 2437,
#          '30': 1230,
#          '9': 1292,
#          '6': 1641,
#          '33': 452,
#          '11': 562,
#          '3': 1195,
#          '29': 477,
#          '25': 697,
#          '12': 140,
#          '14': 1609,
#          '31': 412,
#          '28': 154,
#          '27': 91})

# %% [markdown]
# ### Diagnostic: print out unique institutions that don't have a Carnegie classification in the dataset

# %%
print(set([x['INSTNM'] for x in all_institution_records if x['BASIC2018']  is None]))
# Out:
# {'National University College-Caguas', 'Macon State College', 'Baltimore Hebrew University Inc', 'University of Phoenix-Wichita Campus', 'Vatterott College-St Joseph', 'San Diego Community College District-District Office', 'Harrison College-Muncie', 'University of South Florida-Polytechnic', 'Purdue University-Calumet Campus', 'Ashland University Dwight Schar College of Nursing', 'Brightwood College-Hammond', 'Wentworth Military Academy and College', 'Chamberlain University-Louisiana', 'University of Phoenix-Northwest Arkansas Campus', 'Le Cordon Bleu Institute of Culinary Arts-Pittsburgh', 'ITT Technical Institute-Liverpool', 'Palmer College of Chiropractic-San Jose', 'Globe University-Madison East', 'Universal Technical Institute-Dallas Fort Worth', 'Brown Mackie College-Greenville', 'Sanford-Brown College-Dearborn', 'ITT Technical Institute-San Bernardino', 'Cleveland Institute of Electronics', 'New England School of Acupuncture', 'Bramson ORT College', 'DeVry University-Illinois', 'Anthem Institute-Las Vegas', 'FastTrain of Kendall', 'Everest Institute-North Miami', 'Southeastern Free Will Baptist Bible College', 'California University of Science and Medicine', 'Northwestern Technical College', 'Angley College', 'Lexington Community College', 'University of Phoenix-Memphis Campus', 'Sanford-Brown College-Houston', 'Fortis College-Miami', 'Seminary of the Immaculate Conception', 'Patten University', 'Pennsylvania School of Business', 'AmeriTech College-Provo', 'The Art Institute of St Louis', 'Husson University', 'Southeastern College-Charleston', 'Everest Institute-Fort Lauderdale', 'ITT Technical Institute-Tarentum', 'Le Cordon Bleu College of Culinary Arts-Austin', 'Brown Mackie College-Boise', 'Carnegie Career College', 'DeVry College of New York', 'American Indian College Inc', 'Ivy Tech Community College-Southwest', 'Washington Bible College-Capital Bible Seminary', 'ITT Technical Institute-Cary', 'Chancellor University', 'Johnson & Wales University-Charleston', 'MedTech College-Greenwood Campus', 'San Joaquin Valley College-Lancaster', 'Brown Mackie College-Tucson', 'The University of West Los Angeles', 'South Central Louisiana Technical College-River Parishes Campus', 'ATI College of Health', 'LA College International', 'ITT Technical Institute-Seattle', 'University of Phoenix-Iowa', 'University of Phoenix-West Florida Campus', 'Long Technical College-East Valley', "Saint Patrick's Seminary and University", 'ACT College', 'Blue Cliff College-Houma', 'The University of America', 'Hackensack Meridian School of Medicine', 'DeVry University-Texas', 'Colorado Technical University-Sioux Falls', 'Anthem Career College-Memphis', 'Globe University-Sioux Falls', 'Rasmussen College-Mankato', 'Everest Institute-Cross Lanes', 'Strayer University-Utah', 'Alaska Vocational Technical Center', 'University of Phoenix-Nashville Campus', 'Texas State Technical College-Harlingen', 'Woodbury Institute at Champlain College', 'Remington College-Cleveland West Campus', 'Globe University-Appleton', 'The Chicago School of Professional Psychology at Westwood', 'ITT Technical Institute-Wichita', 'Louisiana Technical College-Slidell Campus', 'Everest College-Reseda', 'Anthem College-Denver', 'Sullivan College of Technology and Design', 'Everest Institute-Hialeah', 'SOLEX College', 'Georgia Military College - Atlanta', 'Lincoln College of Technology-Florence', 'Jesuit School of Theology of Santa Clara University', 'Anthem College-Kansas City', 'Ivy Tech Community College-Columbus', 'Everest University-Melbourne', 'Dade Medical College-Miami Lakes', 'Daymar College-Online', 'ITT Technical Institute-Wyoming', 'Brown Mackie College-St Louis', 'Sanford-Brown College-San Antonio', 'Dade Medical College-West Palm Beach', 'ITT Technical Institute-Youngstown', 'Blue Cliff College-Shreveport', 'All-State Career School', 'MedSpa Careers Institute', 'Southern Polytechnic State University', 'Northwest Louisiana Technical College-Shreveport Campus', 'Kaplan  ...

# %% [markdown]
# # Load and Merge Opportunity Insights Categories
#
# * mrc_table10.csv: [College Level Characteristics from the Opportunity Insights College Scorecard](https://opportunityinsights.org/wp-content/uploads/2018/04/Codebook-MRC-Table-10.pdf)
# * [Opportunity insights data page](https://opportunityinsights.org/data/?geographic_level=0&topic=0&paper_id=536#resource-listing)
#
# Note: I wrote
#
# Columns:
# * **super_opeid**: Institution  OPEID  /    Cluster  ID  when  combining  multiple OPEIDs
# * **name**: Name of Institution / Super-OPEID Cluster
# * **tier**: Selectivity and type combination (constructed from other columns in the dataset):
#   * 1 = Ivy Plus (**this is effectively the only category we can merge, due to [the problem of super-OPEIDS](https://robertkelchen.com/2017/08/21/beware-opeids-and-super-opeids/)**)
#   * 2 = Other elite schools (public and private)
#   * 3 = Highly selective public
#   * 4 = Highly selective private
#   * 5 = Selective public
#   * 6 = Selective private
#   * 7 = Nonselective 4-year public
#   * 8 = Nonselective 4-year private not-for-profit

# %%
important_columns = [
    "super_opeid", # Super OPEID
    "name", #name
    "tier_name", #tier name
    "tier" # the categories of interest
]

op_insights = {}
with codecs.open(data_path + "mrc_table10.csv", encoding='utf-8-sig') as f:
    for row in csv.DictReader(f):
        new_row = {}
        for col in important_columns:
            new_row[col] = row[col]
        op_insights[row['super_opeid']] = new_row
print("{0} opportunity insights categories loaded".format(len(op_insights)))
# Out:
# 2463 opportunity insights categories loaded

# %% [markdown]
# ### Merge IvyPlus
# This is the one Opportunity Insights category we can use.

# %% [markdown]
# #### IvyPlus

# %%
## CONFIRM THAT IVYPLUS CAN BE MERGED
tier_code ='1'
op_insights_group = set([x['name'].strip().lower() for x in op_insights.values() if x['tier']==tier_code])
tier_name = [x['tier_name'] for x in op_insights.values() if x['tier']==tier_code][0].lower().replace(" ",".")

print("{0} total {1}\n".format(len(op_insights_group), tier_name))

for name in op_insights_group:
    found = False
    for institution in institutions.values():
        if(institution['INSTNM'].strip().lower() == name):
            found = True
    print("{0} {1}".format(found, name))
# Out:
# 12 total ivy.plus
#
# True cornell university
# True duke university
# True columbia university in the city of new york
# True yale university
# True dartmouth college
# True stanford university
# True brown university
# True massachusetts institute of technology
# True university of pennsylvania
# True princeton university
# True university of chicago
# True harvard university

# %%
## MERGE IVYPLUS
op_insights_merged = set()
for row in all_institution_records:
    if row['INSTNM'].strip().lower() in op_insights_group:
        row[tier_name] = 1
        op_insights_merged.add(row['INSTNM'])
    else:
        row[tier_name] = 0
        pass
print("{0} {1} merged".format(len(op_insights_merged), tier_name))
op_insights_merged
# Out:
# 12 ivy.plus merged
# {'Brown University',
#  'Columbia University in the City of New York',
#  'Cornell University',
#  'Dartmouth College',
#  'Duke University',
#  'Harvard University',
#  'Massachusetts Institute of Technology',
#  'Princeton University',
#  'Stanford University',
#  'University of Chicago',
#  'University of Pennsylvania',
#  'Yale University'}

# %% [markdown]
# ## Add US News and World Reports Categories
# Documentation is available on the [Best Colleges Ranking Category Definition](https://www.usnews.com/education/best-colleges/articles/ranking-category-definitions) guide (last updated Sept 13, 2020. Accessed August 9, 2021). They are essentially supersets of Carnegie Categories.
#
# Region divisions are taken from the [official US Census regions](https://www2.census.gov/geo/pdfs/maps-data/maps/reference/us_regdiv.pdf), and are stored in this repository in `data/us-census-regions.csv`.

# %%
## See the key under " Load and Merge Carnegie Categories" 
# for the relationship between BASIC2018 codes 
#  and human-readable Carnegie Categories

usnews_categories ={
    "15": "National Universities",
    "16": "National Universities",
    "18": "Regional Universities",
    "19": "Regional Universities",
    "20": "Regional Universities",
    "21": "National Liberal Arts Colleges",
    "22": "Regional Colleges",
    "23": "Regional Colleges",
    "14": "Regional Colleges",
    "24": "Special Focus Four-Year: Faith-Related Institutions",
    "25": "Special Focus Four-Year: Medical Schools & Centers",
    "26": "Special Focus Four-Year: Other Health Professions Schools",
    "27": "Special Focus Four-Year: Engineering Schools",
    "28": "Special Focus Four-Year: Other Technology-Related Schools",
    "29": "Special Focus Four-Year: Business & Management Schools",
    "30": "Special Focus Four-Year: Arts, Music & * Schools",
    "31": "Special Focus Four-Year: Law Schools",
    "32": "Special Focus Four-Year: Other Special Focus Institutions"
}

for row in all_institution_records:
    if row['BASIC2018'] in usnews_categories:
        row['usnews_category']  = usnews_categories[row['BASIC2018']]
    else:
        row['usnews_category']  = None
        
print("Rows (not institutions) with each category:")
Counter([x['usnews_category'] for x in all_institution_records])
# Out:
# Rows (not institutions) with each category:
# Counter({'Regional Universities': 9447,
#          'National Universities': 4094,
#          None: 25712,
#          'Regional Colleges': 7402,
#          'National Liberal Arts Colleges': 3260,
#          'Special Focus Four-Year: Faith-Related Institutions': 2400,
#          'Special Focus Four-Year: Other Special Focus Institutions': 256,
#          'Special Focus Four-Year: Other Health Professions Schools': 2437,
#          'Special Focus Four-Year: Arts, Music & * Schools': 1230,
#          'Special Focus Four-Year: Business & Management Schools': 477,
#          'Special Focus Four-Year: Medical Schools & Centers': 697,
#          'Special Focus Four-Year: Law Schools': 412,
#          'Special Focus Four-Year: Other Technology-Related Schools': 154,
#          'Special Focus Four-Year: Engineering Schools': 91})

# %%
## Load Census Regions
state_region = {}
with open("data/us-census-regions.csv") as f:
    for row in csv.DictReader(f):
        state_region[row['State Code']] = row['Region']
        
        
## add a few regions to follow the US News and World Report
state_region['PR'] = "South"
state_region['MP'] = "West"
state_region['VI'] = "South"
state_region['GU'] = "West"
state_region['AS'] = "West"

## Apply Census Regions to Regional Institutions, following the US News System 
for row in all_institution_records:
    if (row['usnews_category'] in ['Regional Universities', "Regional Colleges"]):
        if(row['STABBR'] in state_region.keys()):
            row['usnews_category'] += "—" + state_region[row['STABBR']]
        else:
            row['usnews_category'] += "—" + row['STABBR']
        
print("Rows (not institutions) with each category:")
Counter([x['usnews_category'] for x in all_institution_records])
# Out:
# Rows (not institutions) with each category:
# Counter({'Regional Universities—South': 3007,
#          'National Universities': 4094,
#          None: 25712,
#          'Regional Colleges—South': 2890,
#          'National Liberal Arts Colleges': 3260,
#          'Special Focus Four-Year: Faith-Related Institutions': 2400,
#          'Special Focus Four-Year: Other Special Focus Institutions': 256,
#          'Regional Universities—West': 1591,
#          'Regional Colleges—West': 1426,
#          'Special Focus Four-Year: Other Health Professions Schools': 2437,
#          'Special Focus Four-Year: Arts, Music & * Schools': 1230,
#          'Special Focus Four-Year: Business & Management Schools': 477,
#          'Special Focus Four-Year: Medical Schools & Centers': 697,
#          'Special Focus Four-Year: Law Schools': 412,
#          'Special Focus Four-Year: Other Technology-Related Schools': 154,
#          'Regional Universities—Northeast': 2454,
#          'Regional Colleges—Northeast': 1174,
#          'Special Focus Four-Year: Engineering Schools': 91,
#          'Regional Universities—Midwest': 2395,
#          'Regional Colleges—Midwest': 1912})

# %% [markdown]
# ## Add Column for HSI/HBCU/Tribal and IVYPLUS

# %%
for record in all_institution_records:
    record['hsi_hbcu_tribal'] = record['HSI'] or record['HBCU'] or record['TRIBAL']
    record['ivy_plus'] = record['ivy.plus']  ==1

# for record in all_institution_records:
#     if record['UNITID'] in institution_pwi.keys():
#         record['pwi'] = institution_pwi[record['UNITID']]>50
#         record['pct_white_2019'] = institution_pwi[record['UNITID']]
#     else:
#         record['pwi'] = None
#         record['pct_white_2019'] = None

# %% [markdown]
# # Add Percentages for Every Level
# This code computes percentages for every group and subgroup in the dataset.

# %%
ranks = ['tenured_full', 'tenured_associate', 'un_tenured_assistant']

## our analysis is only focused on subroups from 2012 onward
## so we only include the demographic characteristics after that time
demo_groups = ['American Indian or Alaska Native',
               'Asian',
               'Black or African American',
               'Hispanic or Latino',
               'Native Hawaiian or Other Pacific Islander',
               'Nonresident alien',
               'Race/ethnicity unknown',
               'Two or more races',
               'White']

## we define the following demographic groups
## as "URM" for this analysis
urm_demo_groups = ['American Indian or Alaska Native',
                   'Black or African American',
                   'Hispanic or Latino',
                   'Native Hawaiian or Other Pacific Islander',
                   'Two or more races']
urm_demo_key    = "black_latino_american_indian_alaska_native_hawaiian_pacific_multiracial"

gender_groups = ['men', 'women']

# %%
#institution_row = [x for x in all_institution_records if x['INSTNM'].find("ornell")>-1 and x['year']=='2019-20'][-1]

# %%
## ALL SUB-GROUPS ARE RECORDED
## AS A PERCENTAGE OF THE RANK

def set_pct_demo_values(institution_row):
    rank_totals = defaultdict(int)
    
    for rank in ranks:
        rank_key = rank + "_" + "Grand_total"
    #     print("{0}: {1}: {2}".format(
    #         rank_key in institution_row.keys(),
    #         institution_row[rank_key],
    #         rank_key))
    
        rank_totals[rank] = 0

        # for each recorded gender
        for gender in gender_groups:
            rank_gender_key = rank_key + "_" + gender

            if(institution_row[rank_gender_key] is not None):
                pct = (float(institution_row[rank_gender_key]) / institution_row[rank_key])*100.
            else:
                pct = None        

            # convention for gender key: replace _Grand_total and add _pct at the end
            institution_row[rank_gender_key.replace("_Grand_total", "") + "_pct"] = pct

    #         print("{0}: {1}: {2}, {3}".format(
    #             rank_gender_key in institution_row.keys(),
    #             institution_row[rank_gender_key],
    #             rank_gender_key,
    #             rank_gender_key.replace("_Grand_total", "") + "_pct"))
    #         print("    {0}".format(pct))        
    
        # for each demographic group
        for demo in demo_groups:
            demo_key = rank + "_" + demo.replace(" ","_").replace("/","_") + "_total"
            
            if(institution_row[demo_key] is not None):
                pct = (float(institution_row[demo_key]) / institution_row[rank_key])*100.
                
                if(demo in urm_demo_groups):
                    rank_totals[rank] += institution_row[demo_key]
                
            else:
                pct = None

            # convention for demo key: replace "_total" with "_pct"
            institution_row[demo_key.replace("_total", "_pct")] = pct

    #         print("{0}: {1}: {2}".format(
    #             demo_key in institution_row.keys(),
    #             institution_row[demo_key],
    #             demo_key))
    #         print("    {0}".format(pct))

            # for each gender within demographic groups
            for gender in gender_groups:
                demo_gender_key = rank + "_" + demo.replace(" ","_").replace("/","_") + "_" + gender      

                if(institution_row[demo_gender_key] is not None and 
                   institution_row[rank_key] is not None and
                   institution_row[rank_key] != 0):
                    pct = (float(institution_row[demo_gender_key]) / float(institution_row[rank_key]) * 100.)
                else:
                    pct = None

                #convention for demo_gender_key: add _pct at end

                institution_row[demo_gender_key+"_pct"] = pct
    #             print("{0}: {1}: {2}".format(
    #                 demo_gender_key in institution_row.keys(),
    #                 institution_row[demo_gender_key],
    #                 demo_gender_key))
    #             print("    {0}".format(pct))
    
    ## add rank totals
    all_rank_total = 0
    for rank in ranks:
        institution_row[rank + "_" + urm_demo_key + "_total"] = rank_totals[rank]
        all_rank_total += rank_totals[rank]
    institution_row["tenured_un_tenured_" + urm_demo_key + "_total"] = all_rank_total
    institution_row["tenured_un_tenured_" + urm_demo_key + "_pct"] = all_rank_total / row['tenured_un_tenured_Grand_total'] if row['tenured_un_tenured_Grand_total'] else None

# %%
## Set demographic values for each institution
for row in all_institution_records:
    set_pct_demo_values(row)

# %% [markdown]
# ### Validate totals

# %%
for record in all_institution_records:
    for rank in ranks:
        rank_key = rank + "_" + "Grand_total"
        calc_total = 0
        for gender in gender_groups:
            rank_gender_key = rank_key + "_" + gender
            if record[rank_gender_key] is not None:
                calc_total += record[rank_gender_key]
        stored_total = 0
        if(record[rank_key] is not None):
            stored_total = record[rank_key]
        
        ## if this runs successfully for every row without an assertion error, then the grand total
        ## is equal to the totals for men and women for every rank.
        assert calc_total == stored_total
print("Validation successful")
# Out:
# Validation successful

# %% [markdown]
# # Write to File

# %%
pd.DataFrame(all_institution_records).to_csv(data_path + "/" + datetime.datetime.now().strftime("%Y%m%d") + "_all_institution_records.csv",
                                             index=False)

# %% [markdown]
# # Generate Tables for Reporting and Visualization
#
# ## Identify Institutions / Rows To Include and Exclude
#
# * Exclude years before 2012-2013
#
# * Institutions that no longer exist or are no longer reporting are omitted from the dataset.
#
# * Institutions reporting two years or fewer are omitted from the dataset.
#
# * Institutions that don't appear in the US News and World Reports classification clusters are omitted.
#
# * Institutions that don't report how many tenured or un-tenured faculty they had in 2019 are omitted from the dataset.

# %%
for record in all_institution_records:
    record['year_int']  = int(record['year'][0:4])

all_institution_records[0]['year_int']
# Out:
# 2004

# %%
## include only records since 2012
institution_records = [x for x in all_institution_records if x['year_int']>=2012]
print("Keeping {0} records out of {1}".format(len(institution_records), len(all_institution_records)))


## include only institutions that reported at least three years
institution_counts = Counter([x['UNITID'] for x in institution_records])
insufficient_records =  {k: v for k, v in institution_counts.items() if v <= 2}
print("Omitting {0} records out of {1}".format(len(insufficient_records), len(institution_records)))

#['tenured_full', 'tenured_associate', 'un_tenured_assistant']

## omit institutions that have no recorded data for full, associate, or assistant
no_tenure_records = set([x['UNITID'] for x in institution_records if x['year_int']==2019 and 
                     (x['tenured_full_Grand_total'] is None or
                      x['tenured_associate_Grand_total'] is None or
                      x['un_tenured_assistant_Grand_total'] is None)])

print("Omitting {0} institutions for having no record of full/associate/assistant totals.".format(len(no_tenure_records)))
# Out:
# Keeping 32228 records out of 58069
# Omitting 594 records out of 32228
# Omitting 2106 institutions for having no record of full/associate/assistant totals.

# %%
institutions_to_include = [
    x['UNITID'] for x in institution_records if
    x['year_int']  == 2019 and           # exists in 2019
    x['usnews_category'] is not None and # has a US News category
    x['UNITID'] not in insufficient_records.keys() and
    x['UNITID'] not in no_tenure_records
]
print("Included institutions: {0} out of {1}".format(len(institutions_to_include), 
                                                     len(set([x['UNITID'] for x in institution_records]))))
# Out:
# Included institutions: 1250 out of 4852

# %%
institution_years = [x for x in institution_records if x['UNITID']  in institutions_to_include]

# %% [markdown]
# ## Generate Timeseries Tables
#
# Tables need:
# * Counts for each category (done)
# * Percentages for each category
# * Estimate, upper/lower confidence interval for a linear regression for percentages in each category, with the specification:
#   * $Y = \beta_0 + \beta_11 \times YEAR + \epsilon$
#
# Summary tables:
# * HBCU + HSI + Tribal compared to the rest
# * Per-category
#
# Non-summary tables:
# * Per-institution

# %% [markdown]
# ### HBCU + HSI + Tribal compared to the rest

# %%
## GENERATE DATASTRUCTURE FOR WHICH KEYS TO DIVIDE BY WHICH

# each column key is the numerator
# with each value the denominator for that key
split_table_cols = {}

for rank in ranks:
    rank_total_key = rank + "_" + "Grand_total"
    split_table_cols[rank_total_key] = rank_total_key

    for gender in gender_groups:
        rank_gender_total_key = rank_total_key + "_" + gender
        #rank_gender_pct_key = rank_gender_total_key.replace("_Grand_total", "") + "_pct"
        split_table_cols[rank_gender_total_key] = rank_total_key

    for demo in demo_groups:
        demo_total_key = rank + "_" + demo.replace(" ","_").replace("/","_") + "_total"
        #demo_pct_key = demo_total_key.replace("_total", "_pct")
        split_table_cols[demo_total_key] = rank_total_key

        for gender in gender_groups:
            demo_gender_total_key = rank + "_" + demo.replace(" ","_").replace("/","_") + "_" + gender      
            #demo_gender_pct_key = demo_gender_total_key + "_pct"
            split_table_cols[demo_gender_total_key] = rank_total_key

# %%
set([x for x in split_table_cols.values()])
# Out:
# {'tenured_associate_Grand_total',
#  'tenured_full_Grand_total',
#  'un_tenured_assistant_Grand_total'}

# %%
split_table_cols
# Out:
# {'tenured_full_Grand_total': 'tenured_full_Grand_total',
#  'tenured_full_Grand_total_men': 'tenured_full_Grand_total',
#  'tenured_full_Grand_total_women': 'tenured_full_Grand_total',
#  'tenured_full_American_Indian_or_Alaska_Native_total': 'tenured_full_Grand_total',
#  'tenured_full_American_Indian_or_Alaska_Native_men': 'tenured_full_Grand_total',
#  'tenured_full_American_Indian_or_Alaska_Native_women': 'tenured_full_Grand_total',
#  'tenured_full_Asian_total': 'tenured_full_Grand_total',
#  'tenured_full_Asian_men': 'tenured_full_Grand_total',
#  'tenured_full_Asian_women': 'tenured_full_Grand_total',
#  'tenured_full_Black_or_African_American_total': 'tenured_full_Grand_total',
#  'tenured_full_Black_or_African_American_men': 'tenured_full_Grand_total',
#  'tenured_full_Black_or_African_American_women': 'tenured_full_Grand_total',
#  'tenured_full_Hispanic_or_Latino_total': 'tenured_full_Grand_total',
#  'tenured_full_Hispanic_or_Latino_men': 'tenured_full_Grand_total',
#  'tenured_full_Hispanic_or_Latino_women': 'tenured_full_Grand_total',
#  'tenured_full_Native_Hawaiian_or_Other_Pacific_Islander_total': 'tenured_full_Grand_total',
#  'tenured_full_Native_Hawaiian_or_Other_Pacific_Islander_men': 'tenured_full_Grand_total',
#  'tenured_full_Native_Hawaiian_or_Other_Pacific_Islander_women': 'tenured_full_Grand_total',
#  'tenured_full_Nonresident_alien_total': 'tenured_full_Grand_total',
#  'tenured_full_Nonresident_alien_men': 'tenured_full_Grand_total',
#  'tenured_full_Nonresident_alien_women': 'tenured_full_Grand_total',
#  'tenured_full_Race_ethnicity_unknown_total': 'tenured_full_Grand_total',
#  'tenured_full_Race_ethnicity_unknown_men': 'tenured_full_Grand_total',
#  'tenured_full_Race_ethnicity_unknown_women': 'tenured_full_Grand_total',
#  'tenured_full_Two_or_more_races_total': 'tenured_full_Grand_total',
#  'tenured_full_Two_or_more_races_men': 'tenured_full_Grand_total',
#  'tenured_full_Two_or_more_races_women': 'tenured_full_Grand_total',
#  'tenured_full_White_total': 'tenured_full_Grand_total',
#  'tenured_full_White_men': 'tenured_full_Grand_total',
#  'tenured_full_White_women': 'tenured_full_Grand_total',
#  'tenured_associate_Grand_total': 'tenured_associate_Grand_total',
#  'tenured_associate_Grand_total_men': 'tenured_associate_Grand_total',
#  'tenured_associate_Grand_total_women': 'tenured_associate_Grand_total',
#  'tenured_associate_American_Indian_or_Alaska_Native_total': 'tenured_associate_Grand_total',
#  'tenured_associate_American_Indian_or_Alaska_Native_men': 'tenured_associate_Grand_total',
#  'tenured_associate_American_Indian_or_Alaska_Native_women': 'tenured_associate_Grand_total',
#  'tenured_associate_Asian_total': 'tenured_associate_Grand_total',
#  'tenured_associate_Asian_men': 'tenured_associate_Grand_total',
#  'tenured_associate_Asian_women': 'tenured_associate_Grand_total',
#  'tenured_associate_Black_or_African_American_total': 'tenured_associate_Grand_total',
#  'tenured_associate_Black_or_African_American_men': 'tenured_associate_Grand_total',
#  'tenured_associate_Black_or_African_American_women': 'tenured_associate_Grand_total',
#  'tenured_associate_Hispanic_or_Latino_total': 'tenured_associate_Grand_total',
#  'tenured_associate_Hispanic_or_Latino_men': 'tenured_associate_Grand_total',
#  'tenured_associate_Hispanic_or_Latino_women': 'tenured_associate_Grand_total',
#  'tenured_associate_Native_Hawaiian_or_Other_Pacific_Islander_total': 'tenured_associate_Grand_total',
#  'tenured_associate_Native_Hawaiian_or_Other_Pacific_Islander_men': 'tenured_associate_Grand_total',
#  'tenured_associate_Native_Hawaiian_or_Other_Pacific_Islander_women': 'tenured_associate_Grand_total',
#  'tenured_associate_Nonresident_alien_total': 'tenured_associate_Grand_total',
#  'tenured_associate_Nonresident_alien_men': 'tenured_associate_Grand_total',
#  'tenured_associate_Nonresident_alien_women': 'tenured_associate_Grand_total',
#  'tenured_associate_Race_ethnicity_unknown_total': 'tenured_associate_Grand_total',
#  'tenured_associate_Race_ethnicity_unknown_men': 'tenured_associate_Grand_total',
#  'tenured_associate_Race_ethnicity_unknown_women': 'tenured_associate_Grand_total',
#  'tenured_associate_Two_or_more_races_total': 'tenured_associate_Grand_total',
#  'tenured_associate_Two_or_more_races_men': 'tenured_associate_Grand_total',
#  'tenured_associate_Two_or_more_races_women': 'tenured_associate_Grand_total',
#  'tenured_associate_White_total': 'tenured_associate_Grand_total',
#  'tenured_associate_White_men': 'tenured_associate_Grand_total',
#  'tenured_associate_White_women': 'tenured_associate_Grand_total',
#  'un_tenured_assistant_Grand_total': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Grand_total_men': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Grand_total_women': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_American_Indian_or_Alaska_Native_total': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_American_Indian_or_Alaska_Native_men': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_American_Indian_or_Alaska_Native_women': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Asian_total': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Asian_men': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Asian_women': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Black_or_African_American_total': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Black_or_African_American_men': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Black_or_African_American_women': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Hispanic_or_Latino_total': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Hispanic_or_Latino_men': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Hispanic_or_Latino_women': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Native_Hawaiian_or_Other_Pacific_Islander_total': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Native_Hawaiian_or_Other_Pacific_Islander_men': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Native_Hawaiian_or_Other_Pacific_Islander_women': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Nonresident_alien_total': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Nonresident_alien_men': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Nonresident_alien_women': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Race_ethnicity_unknown_total': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Race_ethnicity_unknown_men': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Race_ethnicity_unknown_women': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Two_or_more_races_total': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Two_or_more_races_men': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_Two_or_more_races_women': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_White_total': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_White_men': 'un_tenured_assistant_Grand_total',
#  'un_tenured_assistant_White_women': 'un_tenured_assistant_Grand_total'}

# %%
def year_row():
    return defaultdict(int)

## exclude from split tables any subgroups where the denominator
## of faculty for a given rank is 0. That would mean that no institutions
## reported any faculty in that rank that year

def return_split_table(record_years, split_table_key):        
    included_years = set([x['year_int'] for x in record_years])

    subgroup_table_rows = []

    for subgroup_key in set([x[split_table_key] for x in record_years]):
        row = defaultdict(year_row)        

        subgroup_institution_years = [x for x in record_years if x[split_table_key] == subgroup_key]

        unique_denominator_keys = set([x for x in split_table_cols.values()])

        for institution_year in subgroup_institution_years:
            
            ## TODO: for some reason, this code is double-counting denominators. FIx.
            for denominator_key in unique_denominator_keys:
                if(institution_year[denominator_key] is not None):
                    row[institution_year['year_int']][denominator_key+"_sum"] += institution_year[denominator_key]

            for numerator_key, denominator_key in split_table_cols.items():
                ## only add the numerator if the denominator is not None (likely rare)
                if(institution_year[numerator_key] is not None and institution_year[denominator_key] is not None):
                    row[institution_year['year_int']][numerator_key + "_sum"] += institution_year[numerator_key]
                elif(institution_year[denominator_key] is None and institution_year[numerator_key] is not None):
                    print("denominator key None but numerator exists!!!")

        # patch the tenured and un-tenured sums. TODO: fix the code block starting at line 22
        for year in included_years:
            row[year]['tenured_full_Grand_total_sum'] = row[year]['tenured_full_Grand_total_women_sum'] + row[year]['tenured_full_Grand_total_men_sum']
            row[year]['tenured_associate_Grand_total_sum'] = row[year]['tenured_associate_Grand_total_women_sum'] + row[year]['tenured_associate_Grand_total_men_sum']
            row[year]['un_tenured_assistant_Grand_total_sum'] = row[year]['un_tenured_assistant_Grand_total_women_sum'] + row[year]['un_tenured_assistant_Grand_total_men_sum']
            row[year]['tenured_un_tenured_Grand_total_sum'] = row[year]['tenured_full_Grand_total_sum'] + row[year]['tenured_associate_Grand_total_sum'] + row[year]['un_tenured_assistant_Grand_total_sum']
            
            ## add in joint tenured and un_tenured totals
            ## and joint tenured and un_tenured totals for URM
            total_tt_urm_key = "tenured_un_tenured_" + urm_demo_key + "_total_sum"
            row[year][total_tt_urm_key]  = 0
            for group in urm_demo_groups:
                tf_key  = "tenured_full_" + group.replace(" ","_").replace("/","_") + "_total_sum"
                ta_key  = "tenured_associate_" + group.replace(" ","_").replace("/","_") + "_total_sum"
                ut_key  = "un_tenured_assistant_" + group.replace(" ","_").replace("/","_") + "_total_sum"
                
                row[year][total_tt_urm_key] += row[year][tf_key]
                row[year][total_tt_urm_key] += row[year][ta_key]
                row[year][total_tt_urm_key] += row[year][ut_key]
            
            ## now add pct URM tenure track faculty
            if(row[year]['tenured_un_tenured_Grand_total_sum']):
                row[year]["tenured_un_tenured_" + urm_demo_key + "_total_pct"] = \
                    float(row[year][total_tt_urm_key]) / float(row[year]['tenured_un_tenured_Grand_total_sum']) 
            else:
                row[year]["tenured_un_tenured_" + urm_demo_key + "_total_pct"] = None
                    
        
        for year in included_years:
            
            zero_denominator = False
            
            for numerator_key, denominator_key in split_table_cols.items():
                try:
                    row[year][numerator_key + "_pct"] = (row[year][numerator_key + "_sum"] / row[year][denominator_key + "_sum"])*100.
                except ZeroDivisionError:
                    row[year][numerator_key + "_pct"] = None
                    zero_denominator = True

                    
            row[year]['year'] = year
            row[year]["subgroup"]  = split_table_key
            row[year]["subgroup_value"] = subgroup_key
            
            row[year]['num_institutions'] = len(set([x['UNITID'] for x in subgroup_institution_years if x['year_int'] == year]))
                     
            # skip if there's a zero denominator
            if(zero_denominator):
                print("Zero denominator: {0}, {1}, {2}".format(year, split_table_key, subgroup_key))
            else:
                subgroup_table_rows.append(row[year])
    return subgroup_table_rows

# %%
def validate_urm_faculty_columns(split_table_row):
    urm_total = 0
    total_tt_urm_key = "tenured_un_tenured_" + urm_demo_key + "_total_sum"
    
    for group in urm_demo_groups:
        tf_key  = "tenured_full_" + group.replace(" ","_").replace("/","_") + "_total_sum"
        ta_key  = "tenured_associate_" + group.replace(" ","_").replace("/","_") + "_total_sum"
        ut_key  = "un_tenured_assistant_" + group.replace(" ","_").replace("/","_") + "_total_sum"
        urm_total += split_table_row[tf_key]
        urm_total += split_table_row[ta_key]
        urm_total += split_table_row[ut_key]

    assert urm_total == split_table_row[total_tt_urm_key]

# %% [markdown]
# ### Generate Tables

# %%
## confirm that there are only two values
print(set([x['ivy_plus'] for x in institution_years]))

## generate split table, one row for every year
ivy_plus_table = return_split_table(institution_years, 'ivy_plus')

## validate totals
[validate_urm_faculty_columns(x) for x in ivy_plus_table]
pass
# Out:
# {False, True}

# %%
validate_urm_faculty_columns(ivy_plus_table[0])

# %%
## confirm that there are only two values
print(set([x['hsi_hbcu_tribal'] for x in institution_years]))

## generate split table, one row for every year
hsi_hbcu_tribal_table = return_split_table(institution_years, 'hsi_hbcu_tribal')
# Out:
# {'0', '1'}

# %%
## confirm values
print(set([x['usnews_category'] for x in institution_years]))

## generate split table, one row for every year
usnews_category_table = return_split_table(institution_years, 'usnews_category')
# Out:
# {'Special Focus Four-Year: Medical Schools & Centers', 'Regional Universities—West', 'Special Focus Four-Year: Engineering Schools', 'Regional Colleges—Midwest', 'Special Focus Four-Year: Faith-Related Institutions', 'Regional Colleges—South', 'Special Focus Four-Year: Business & Management Schools', 'Special Focus Four-Year: Arts, Music & * Schools', 'Regional Colleges—Northeast', 'Regional Colleges—West', 'Special Focus Four-Year: Other Health Professions Schools', 'Regional Universities—Northeast', 'Regional Universities—Midwest', 'Special Focus Four-Year: Other Special Focus Institutions', 'Special Focus Four-Year: Other Technology-Related Schools', 'Special Focus Four-Year: Law Schools', 'National Liberal Arts Colleges', 'Regional Universities—South', 'National Universities'}
# Zero denominator: 2012, usnews_category, Special Focus Four-Year: Business & Management Schools
# Zero denominator: 2012, usnews_category, Special Focus Four-Year: Other Technology-Related Schools
# Zero denominator: 2014, usnews_category, Special Focus Four-Year: Other Technology-Related Schools

# %%
#institution_years[0].keys()

# %%
## confirm values for carnegie categories
print(set([x['BASIC2018'] for x in institution_years]))
carnegie_category_table = return_split_table(institution_years, 'BASIC2018')
# Out:
# {'30', '24', '23', '22', '19', '18', '31', '26', '20', '14', '32', '28', '21', '16', '15', '25', '27', '29'}
# Zero denominator: 2012, BASIC2018, 28
# Zero denominator: 2014, BASIC2018, 28
# Zero denominator: 2012, BASIC2018, 29

# %% [markdown]
# ### Generate Linear Regressions

# %%
## the code accepts a custom year key so it can be used
## on the summary tables for collections of institutions
## as well as records for individual institutions
def generate_regression_table(institution_table, year_key = 'year'):
    result_rows = []

    zero_year = 2012

    subgroup_key   = institution_table[0]['subgroup']
    for subgroup_value in list(set([x['subgroup_value'] for x in institution_table])):


        table_df = pd.DataFrame([x for x in institution_table if 
                                          x['subgroup'] == subgroup_key and 
                                          x['subgroup_value'] == subgroup_value])
        table_df['year_num'] = table_df[year_key] - zero_year


        for dv in [x for x in institution_table[0].keys() if x.find("_pct")>-1]:

            formula_text = formula = dv + " ~ year_num"
            mod = smf.ols(formula_text, data=table_df)
            modfit = mod.fit()

            row = {"subgroup"      : subgroup_key,
                   "subgroup_value": subgroup_value,
                   "min_year"      : min([x['year'] for x in institution_table]),
                   "max_year"      : max([x['year'] for x in institution_table]),
                   "dv"            : dv,
                   "formula"       : formula_text,
                   "Intercept"     : modfit.params.Intercept,
                   "year_estimate" : modfit.params.year_num,
                   "year_pvalue"   : modfit.pvalues.year_num,
                   "year_stderr"   : modfit.bse.year_num
                   }
            result_rows.append(row)

    return result_rows

# %%
usnews_regression_table = generate_regression_table(usnews_category_table)
ivy_plus_regression_table = generate_regression_table(ivy_plus_table)
hsi_hbcu_tribal_regression_table = generate_regression_table(hsi_hbcu_tribal_table)
carnegie_regression_table = generate_regression_table(carnegie_category_table)

# %% [markdown]
# ### Write Summary and Regression Tables to Files

# %%
pd.DataFrame(usnews_regression_table).to_csv(data_path + "/" + datetime.datetime.now().strftime("%Y%m%d") + 
                                             "_usnews_regression_table.csv",
                                             index=False)
pd.DataFrame(usnews_category_table).to_csv(data_path + "/" + datetime.datetime.now().strftime("%Y%m%d") + 
                                             "_usnews_summary_table.csv",
                                             index=False)

pd.DataFrame(ivy_plus_regression_table).to_csv(data_path + "/" + datetime.datetime.now().strftime("%Y%m%d") + 
                                             "_ivy_plus_regression_table.csv",
                                             index=False)
pd.DataFrame(ivy_plus_table).to_csv(data_path + "/" + datetime.datetime.now().strftime("%Y%m%d") + 
                                             "_ivy_plus_summary_table.csv",
                                             index=False)


pd.DataFrame(hsi_hbcu_tribal_regression_table).to_csv(data_path + "/" + datetime.datetime.now().strftime("%Y%m%d") + 
                                             "_hsi_hbcu_tribal_regression_table.csv",
                                             index=False)
pd.DataFrame(hsi_hbcu_tribal_table).to_csv(data_path + "/" + datetime.datetime.now().strftime("%Y%m%d") + 
                                             "_hsi_hbcu_tribal_summary_table.csv",
                                             index=False)

pd.DataFrame(carnegie_regression_table).to_csv(data_path + "/" + datetime.datetime.now().strftime("%Y%m%d") + 
                                             "_carnegie_regression_table.csv",
                                             index=False)
pd.DataFrame(carnegie_category_table).to_csv(data_path + "/" + datetime.datetime.now().strftime("%Y%m%d") + 
                                             "_carnegie_summary_table.csv",
                                             index=False)

# %% [markdown]
# # Produce Regression Tables for Every Institution in the Dataset

# %%
counter = 1

institution_regression_table = []
for institution_id in set([x['UNITID'] for x in institution_years]):
    institution_subset_rows = [x for x in institution_years if x['UNITID'] == institution_id]
    for row in institution_subset_rows:
        row['subgroup'] = 'institution'
        row['subgroup_value'] = row['INSTNM']
    regression_rows = generate_regression_table(institution_subset_rows, year_key='year_int')
    for regression in regression_rows:
        regression['carnegie_category'] = institution_subset_rows[0]['BASIC2018']
        regression['usnews_category'] = institution_subset_rows[0]['usnews_category']
        regression['ivy_plus'] = institution_subset_rows[0]['ivy_plus']
        regression['hsi_hbcu_tribal'] = institution_subset_rows[0]['hsi_hbcu_tribal']
    institution_regression_table += regression_rows
    
    if counter % 10 == 0:
        sys.stdout.write(".")
        sys.stdout.flush()
    counter += 1
# Out:
# .............................................................................................................................

# %%
#institution_subset_rows[0].keys()

# %%
print("Computed {0} regression tables for {1} institutions.".format(len(institution_regression_table), 
                                                                    len(set([x['subgroup_value'] for x in institution_regression_table]))))
# Out:
# Computed 110000 regression tables for 1241 institutions.

# %% [markdown]
# ### Write regression tables for individual institutions

# %%
pd.DataFrame(institution_regression_table).to_csv(data_path + "/" + datetime.datetime.now().strftime("%Y%m%d") + 
                                             "_institution_regression_tables.csv",
                                             index=False)

# %% [markdown]
# # Generate Tables of Total Tenured and Tenure Track Faculty for the Article
#
# Documentation from IPEDS201213TablesDoc:
# > "Does institution have a tenure system?
# > This variable is derived so that users can disaggregate those employees that are nontenured not on tenure track from those employees that are in an institution with no tenure system. Both EAP and Fall Staff components collect these data using 1 data  field which makes it very difficult to produce tables on tenure.  It is assumed that if all employees are reported in the nontenured not on track/no tenure system column/row, then the institution has no tenure system.

# %%
tenure_table_cols = {}

for status in ['tenured', 'un_tenured']:
    status_total_key = status + "_" + "Grand_total"
    tenure_table_cols[status_total_key] = status_total_key

    for gender in gender_groups:
        status_gender_total_key = status_total_key + "_" + gender
        #rank_gender_pct_key = rank_gender_total_key.replace("_Grand_total", "") + "_pct"
        tenure_table_cols[status_gender_total_key] = status_total_key

    for demo in demo_groups:
        demo_total_key = status + "_" + demo.replace(" ","_").replace("/","_") + "_total"
        #demo_pct_key = demo_total_key.replace("_total", "_pct")
        tenure_table_cols[demo_total_key] = status_total_key

        for gender in gender_groups:
            demo_gender_total_key = status + "_" + demo.replace(" ","_").replace("/","_") + "_" + gender      
            #demo_gender_pct_key = demo_gender_total_key + "_pct"
            tenure_table_cols[demo_gender_total_key] = status_total_key
            
tenure_table_cols
# Out:
# {'tenured_Grand_total': 'tenured_Grand_total',
#  'tenured_Grand_total_men': 'tenured_Grand_total',
#  'tenured_Grand_total_women': 'tenured_Grand_total',
#  'tenured_American_Indian_or_Alaska_Native_total': 'tenured_Grand_total',
#  'tenured_American_Indian_or_Alaska_Native_men': 'tenured_Grand_total',
#  'tenured_American_Indian_or_Alaska_Native_women': 'tenured_Grand_total',
#  'tenured_Asian_total': 'tenured_Grand_total',
#  'tenured_Asian_men': 'tenured_Grand_total',
#  'tenured_Asian_women': 'tenured_Grand_total',
#  'tenured_Black_or_African_American_total': 'tenured_Grand_total',
#  'tenured_Black_or_African_American_men': 'tenured_Grand_total',
#  'tenured_Black_or_African_American_women': 'tenured_Grand_total',
#  'tenured_Hispanic_or_Latino_total': 'tenured_Grand_total',
#  'tenured_Hispanic_or_Latino_men': 'tenured_Grand_total',
#  'tenured_Hispanic_or_Latino_women': 'tenured_Grand_total',
#  'tenured_Native_Hawaiian_or_Other_Pacific_Islander_total': 'tenured_Grand_total',
#  'tenured_Native_Hawaiian_or_Other_Pacific_Islander_men': 'tenured_Grand_total',
#  'tenured_Native_Hawaiian_or_Other_Pacific_Islander_women': 'tenured_Grand_total',
#  'tenured_Nonresident_alien_total': 'tenured_Grand_total',
#  'tenured_Nonresident_alien_men': 'tenured_Grand_total',
#  'tenured_Nonresident_alien_women': 'tenured_Grand_total',
#  'tenured_Race_ethnicity_unknown_total': 'tenured_Grand_total',
#  'tenured_Race_ethnicity_unknown_men': 'tenured_Grand_total',
#  'tenured_Race_ethnicity_unknown_women': 'tenured_Grand_total',
#  'tenured_Two_or_more_races_total': 'tenured_Grand_total',
#  'tenured_Two_or_more_races_men': 'tenured_Grand_total',
#  'tenured_Two_or_more_races_women': 'tenured_Grand_total',
#  'tenured_White_total': 'tenured_Grand_total',
#  'tenured_White_men': 'tenured_Grand_total',
#  'tenured_White_women': 'tenured_Grand_total',
#  'un_tenured_Grand_total': 'un_tenured_Grand_total',
#  'un_tenured_Grand_total_men': 'un_tenured_Grand_total',
#  'un_tenured_Grand_total_women': 'un_tenured_Grand_total',
#  'un_tenured_American_Indian_or_Alaska_Native_total': 'un_tenured_Grand_total',
#  'un_tenured_American_Indian_or_Alaska_Native_men': 'un_tenured_Grand_total',
#  'un_tenured_American_Indian_or_Alaska_Native_women': 'un_tenured_Grand_total',
#  'un_tenured_Asian_total': 'un_tenured_Grand_total',
#  'un_tenured_Asian_men': 'un_tenured_Grand_total',
#  'un_tenured_Asian_women': 'un_tenured_Grand_total',
#  'un_tenured_Black_or_African_American_total': 'un_tenured_Grand_total',
#  'un_tenured_Black_or_African_American_men': 'un_tenured_Grand_total',
#  'un_tenured_Black_or_African_American_women': 'un_tenured_Grand_total',
#  'un_tenured_Hispanic_or_Latino_total': 'un_tenured_Grand_total',
#  'un_tenured_Hispanic_or_Latino_men': 'un_tenured_Grand_total',
#  'un_tenured_Hispanic_or_Latino_women': 'un_tenured_Grand_total',
#  'un_tenured_Native_Hawaiian_or_Other_Pacific_Islander_total': 'un_tenured_Grand_total',
#  'un_tenured_Native_Hawaiian_or_Other_Pacific_Islander_men': 'un_tenured_Grand_total',
#  'un_tenured_Native_Hawaiian_or_Other_Pacific_Islander_women': 'un_tenured_Grand_total',
#  'un_tenured_Nonresident_alien_total': 'un_tenured_Grand_total',
#  'un_tenured_Nonresident_alien_men': 'un_tenured_Grand_total',
#  'un_tenured_Nonresident_alien_women': 'un_tenured_Grand_total',
#  'un_tenured_Race_ethnicity_unknown_total': 'un_tenured_Grand_total',
#  'un_tenured_Race_ethnicity_unknown_men': 'un_tenured_Grand_total',
#  'un_tenured_Race_ethnicity_unknown_women': 'un_tenured_Grand_total',
#  'un_tenured_Two_or_more_races_total': 'un_tenured_Grand_total',
#  'un_tenured_Two_or_more_races_men': 'un_tenured_Grand_total',
#  'un_tenured_Two_or_more_races_women': 'un_tenured_Grand_total',
#  'un_tenured_White_total': 'un_tenured_Grand_total',
#  'un_tenured_White_men': 'un_tenured_Grand_total',
#  'un_tenured_White_women': 'un_tenured_Grand_total'}

# %%
def return_year_summaries(record_years):    
    record_years = [x for x in all_institution_records if x['year_int']>=2013]
    included_years = set([x['year_int'] for x in record_years])

    subgroup_table_rows = []
    unique_denominator_keys = list(set([x for x in tenure_table_cols.values()]))

    row = defaultdict(year_row)        

    for institution_year in record_years:
        year = institution_year['year_int']

        ## WARNING: THIS CODE IS SOMEHOW PRODUCING 2X THE CORRECT VALUE
        iterations = 0
        for denominator_key in unique_denominator_keys:
            if(institution_year[denominator_key] is not None):
                row[year][denominator_key+"_sum"] += institution_year[denominator_key]
                iterations += 1
        assert iterations <= 2

        for numerator_key, denominator_key in tenure_table_cols.items():
            ## only add the numerator if the denominator is not None (likely rare)
            if(institution_year[numerator_key] is not None and institution_year[denominator_key] is not None):
                row[year][numerator_key + "_sum"] += institution_year[numerator_key]
            elif(institution_year[denominator_key] is None and institution_year[numerator_key] is not None):
                print("denominator key None but numerator exists!!!")

        ## calculate sum of grand totals
#        if('tenured_un_tenured_Grand_total_sum' not in row[year].keys()):
#            row[year]['tenured_un_tenured_Grand_total_sum'] = 0
            
        row[year]['tenured_un_tenured_Grand_total_sum'] += institution_year['tenured_un_tenured_Grand_total']

    # patch the tenured and un-tenured sums. TODO: fix the code block starting at line 13
    for year in included_years:
        row[year]['tenured_Grand_total_sum'] = row[year]['tenured_Grand_total_women_sum'] + row[year]['tenured_Grand_total_men_sum']
        row[year]['un_tenured_Grand_total_sum'] = row[year]['un_tenured_Grand_total_women_sum'] + row[year]['un_tenured_Grand_total_men_sum']
        assert row[year]['tenured_un_tenured_Grand_total_sum'] == row[year]['tenured_Grand_total_sum'] + row[year]['un_tenured_Grand_total_sum']

    for year in included_years:

        zero_denominator = False

        for numerator_key, denominator_key in tenure_table_cols.items():
            try:
                row[year][numerator_key + "_pct"] = (row[year][numerator_key + "_sum"] / row[year][denominator_key + "_sum"])*100.
            except ZeroDivisionError:
                row[year][numerator_key + "_pct"] = None
                zero_denominator = True

        row[year]['year'] = year            
        row[year]['num_institutions'] = len(set([x['UNITID'] for x in record_years if x['year_int'] == year]))

        ## Generate total for tenured + un_tenured
#        row[year]['tenured_un_tenured_Grand_total'] = row[year]['tenured_Grand_total'] + row[year]['un_tenured_Grand_total']
        
        ## Generate demographic percentages for each year
        for demo in demo_groups:
            demo_total = 0
            for status in ['tenured', 'un_tenured']:
                demo_total_key = status + "_" + demo.replace(" ","_").replace("/","_") + "_total_sum"
                demo_total += row[year][demo_total_key]
            
            total_key = 'tenured_un_tenured_' + demo.replace(" ","_").replace("/","_") + "_total_sum"
            row[year][total_key] = demo_total
            row[year][total_key.replace("sum","pct")] = (float(demo_total) / float(row[year]['tenured_un_tenured_Grand_total_sum'])) * 100.
            

        # skip if there's a zero denominator
        if(zero_denominator):
            print("Zero denominator: {0}: {1}".format(year, denominator_key))
        else:
            subgroup_table_rows.append(row[year])
            
    return subgroup_table_rows

# %%
year_summary_table = return_year_summaries([x for x in all_institution_records if x['year_int']>=2013])

# %%
#[x for x in year_summary_table[0].keys() if x.find("_sum")>-1]
len(year_summary_table[0].keys())
# Out:
# 141

# %% [markdown]
# ### Write table for year summaries

# %%
pd.DataFrame(year_summary_table).to_csv(data_path + "/" + datetime.datetime.now().strftime("%Y%m%d") + 
                                             "_year_summary_table.csv",
                                             index=False)
